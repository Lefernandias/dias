# %%
#        # Script de login no KPL

import pyautogui
import time

pyautogui.PAUSE = 1

# executa o aplicativo do abacos e faz login
def loga():
    #pyautogui.alert ('Processo cadastro de unidade de negocio será iniciado! ') # exibe mensagem no desktop para inico do programa
    pyautogui.press('winleft') # função que clica no botão windows do mouse 
    time.sleep(1) #tempo de espera para iniciar proxima função
    pyautogui.write('C:\Aplicacao\ABACOS.EXE')  # insere o endereço do executavel do kpl na barra de busca do menu do desktop
    pyautogui.PAUSE = 1.0 #tempo de espera para iniciar proxima função 
    pyautogui.press('enter') #Executa o endereço inserido na busca
    time.sleep(1) #tempo de espera para iniciar proxima função 
    pyautogui.moveTo (672, 672) # digitar no campo que informa o nome do usuário
    pyautogui.write('leandrofer') # função que insere o nome do usuário
    pyautogui.PAUSE = 0.5 #tempo de espera para iniciar proxima inserção
    pyautogui.press('enter') #função que da enter para cursor pular de campoS
    #pyautogui.moveTo (667, 398)
    pyautogui.write('Synapcom2022@@') #função que insere a senha do usuário
    pyautogui.PAUSE = 0.8 #tempo de espera para iniciar proxima inserçãoS
    pyautogui.moveTo (638, 436) # clica no campo de logar
    pyautogui.doubleClick(button='left') # duplo clique na campo de logar
    time.sleep(10) #tempo de espera para finalizar o programa
    #pyautogui.alert ('Logado com sucesso no Abacos!') #Fim do programa
    #time.sleep(30)


# entra na tela de nota fiscal de entrada
def menu():
    #pyautogui.alert ('Processo de aprovação de notas fiscais será iniciado ')
    time.sleep(7) #aguarda 10 segundos 
    pyautogui.moveTo (67, 637) #clica na barra de busca do menu
    time.sleep(5) #aguarda 1 segundoc
    pyautogui.doubleClick(button='left') #duplo click na barra
    pyautogui.write('digitar') #Digita o atalho
    pyautogui.press('enter') #função que da enter para cursor pular de campo
    pyautogui.moveTo (112, 302) # Point(x=112, y=302)
    pyautogui.doubleClick(button='left')
    time.sleep(4)

# insere os parametros de busca das notas fiscais
def busca(): #busca
    pyautogui.PAUSE = 1
    pyautogui.press('TAB')
    pyautogui.press('TAB')
    pyautogui.press('TAB')
    pyautogui.write('DIGI')
    pyautogui.press('enter')
    #pyautogui.press('TAB')
    pyautogui.press('TAB')
    pyautogui.write('SY - COMPRAS')
    pyautogui.press('enter')
    pyautogui.press('TAB')
    #pyautogui.press('TAB')
    pyautogui.write('01082021')
    pyautogui.press('enter')
    pyautogui.write('30092021')
    pyautogui.press('TAB')
    pyautogui.write('282828')
    pyautogui.hotkey('shift', 'enter')
    time.sleep(3)
    
    #pyautogui.moveTo (321, 208) # posiciona o cursor no campo de unidade de negocio
    #pyautogui.doubleClick(button='left') # efetua duplo clique no campo de unidadde de negocio
    #pyautogui.write('51') # inserer o numero da unidade de negocio
    #pyautogui.moveTo (321, 208) # posiciona o cursor no campo de código de fomercedor
    #pyautogui.doubleClick(button='left') # efetua duplo clique no campo de código do fornecedor
    #pyautogui.write('282828') # insere a informação de status aguardando aprovação
    #pyautogui.doubleClick(button='left') # efetua duplo clique no campo de
    #pyautogui.press('enter') # insere enter para fixar o numero da unidade de negocio no campo
    #pyautogui.press('TAB') # preciosa tab do teclado para pular para o campo status
    #pyautogui.write('AGUARDANDO AP') # insere a informação de status aguardando aprovação
    #pyautogui.press('enter') # preciona enear para fixar a informação no campo
    #time.sleep(2) #aguarda 1 segundo para o abacos realizar a busca
    #pyautogui.hotkey('shift', 'enter')
    #pyautogui.moveTo (1337, 170) #posciona o cursor do mouse para o botão de filtrar
    #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar 
    #time.sleep(3) #aguarda 1 segundo para o abacos realizar a busca
    
    
def atualiza(): 
    
    pyautogui.hotkey('shift', 'enter')
    #pyautogui.moveTo (1337, 170) #posciona o cursor do mouse para o botão de filtrar
    #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar 
    time.sleep(2) #aguarda 1 segundo para o abacos realizar a busca


def my_function4():
    time.sleep(0.4)
    pyautogui.moveTo (92, 396)  # Posiciona o cursor na lista de nota e verifica se existe registros
    pyautogui.click(button='left') #clica na posiçõa da listagem da nota
    time.sleep(0.4)# clica na posiçõa da listagem da nota
    

def my_function6():    
    pyautogui.moveTo (92, 396) #posiciona o mouse para a primeira posição da listagem das notas fiscais
    pyautogui.click(button='left') # executa um clique simples para marcar a nota fiscal
    time.sleep(0.4)# clica na posiçõa da listagem da nota
    pyautogui.press('c')
   # pyautogui.moveTo (803, 96) #posicona  mouse na função de concluir a nota fiscal
   # pyautogui.doubleClick(button='left') # executa um clique duplo para concluir a nota fiscal
    time.sleep(1) # aguarda 3 segundo para o abacos carregar a tela da nota fiscal
    pyautogui.moveTo (748, 138) # posiciona o mouse no inicio da janela da validação da nota fiscal
    time.sleep(3)
    pyautogui.doubleClick(button='left')
    time.sleep(0.8)# executa um clique duplo na janela para maximizar a janela
    pyautogui.moveTo (417, 104)
    time.sleep(0.3)
    pyautogui.click(button='left')
    time.sleep(1)
    
    
    
def my_function61():    
    pyautogui.moveTo (92, 396) #posiciona o mouse para a primeira posição da listagem das notas fiscais
    pyautogui.click(button='left') # executa um clique simples para marcar a nota fiscal
    time.sleep(0.4)# clica na posiçõa da listagem da nota
    pyautogui.press('c')
    #pyautogui.moveTo (803, 96) #posicona  mouse na função de concluir a nota fiscal
    #pyautogui.doubleClick(button='left') # executa um clique duplo para concluir a nota fiscal
    time.sleep(3) # aguarda 3 segundo para o abacos carregar a tela da nota fiscal
    pyautogui.moveTo (748, 138) # posiciona o mouse no inicio da janela da validação da nota fiscal
    time.sleep(3)
    pyautogui.doubleClick(button='left')
    time.sleep(0.8)# executa um clique duplo na janela para maximizar a janela
    pyautogui.moveTo (417, 104)
    time.sleep(0.3)
    pyautogui.click(button='left')
    time.sleep(1)
    

def my_function7():
    pyautogui.press('ESC')
    time.sleep(1)
    pyautogui.press('ESC')
    time.sleep(1)
    print ('Fechou Programa') #fecha e mata a programa
    pyautogui.FAILSAFE = True
    exit()
    pyautogui.alert ('Acabou ')
    
def my_function71():
    pyautogui.press('ESC')
    time.sleep(1)
    pyautogui.press('ESC')
    time.sleep(1)
    print ('Fechou Programa') #fecha e mata a programa
    pyautogui.FAILSAFE = True
    exit()
    pyautogui.alert ('Acabou ')
    
def my_function8():
    time.sleep(1)
    pyautogui.press('F10')
    pyautogui.press('S')
    pyautogui.press('Enter')
    pyautogui.write('girafa')
    pyautogui.press('Enter')
    time.sleep(5)
    atualiza()
    time.sleep(1)
    loopazul2()
    time.sleep(1)
    loopverde2()
    time.sleep(1)
    print('Aprovou NF')
    
    
def my_function81():
    time.sleep(1)
    pyautogui.press('F10')
    pyautogui.press('S')
    pyautogui.press('Enter')
    pyautogui.write('girafa')
    pyautogui.press('Enter')
    time.sleep(5)
    atualiza()
    time.sleep(1)
    loopazul2()
    time.sleep(1)
    loopverde2()
    time.sleep(1)
    print('Aprovou NF')
    
def my_function9():
    pyautogui.press('F5')
    pyautogui.press('S')
    pyautogui.press('S')
    #pyautogui.press('Enter')
    #pyautogui.write('girafa')
    #pyautogui.press('Enter')
    time.sleep(1)
    atualiza()
    time.sleep(1)
    #pyautogui.press('S')
    print('Rejeitou NF')
    time.sleep(1)
    loopazul2()
    time.sleep(1)
    loopverde2()
    time.sleep(1)
    
def my_function91():
    pyautogui.press('F5')
    pyautogui.press('S')
    pyautogui.press('S')
    #pyautogui.press('Enter')
    #pyautogui.write('girafa')
    #pyautogui.press('Enter')
    time.sleep(1)
    atualiza()
    time.sleep(1)
    #pyautogui.press('S')
    print('Rejeitou NF')
    time.sleep(1)
    loopazul2()
    time.sleep(1)
    loopverde2()
    time.sleep(1)
    
    
def loopazul():
    
    pyautogui.PAUSE = 2.0 
    pix2 = pyautogui.pixel(74, 395)# coleta a cor da linha da nota buscada
    pyautogui.FAILSAFE = True
    time.sleep(3)
    pix2[2] # retorna o valor da linha azul do retorno da função anterior
    a = pix2[2]
    b = 215
    time.sleep(1)

    if a == b:
     my_function6()

    else:
     my_function7()

def loopazul2():
    
    pyautogui.PAUSE = 2.0
    pix2 = pyautogui.pixel(74, 395)# coleta a cor da linha da nota buscada
    pyautogui.FAILSAFE = True
    time.sleep(3)
    pix2[2] # retorna o valor da linha azul do retorno da função anterior
    a = pix2[2]
    b = 215
    time.sleep(1)

    if a == b:
     my_function61()

    else:
     my_function71()

def loopverde():
    
    pyautogui.PAUSE = 3.0
    pix = pyautogui.pixel(417, 104)# verifica na linha da nota fiscal a cor do status
    time.sleep(2)
    pix[1] # retorna o valor da linha verde do retorno da função anterior
    a = pix[1]
    b = 128
    time.sleep(1)

    if a == b:
     my_function8()
    
    else:
     my_function9()
    
def loopverde2():
    
    pyautogui.PAUSE = 3.0
    pix = pyautogui.pixel(417, 104)# verifica na linha da nota fiscal a cor do status
    time.sleep(2)
    pix[1] # retorna o valor da linha verde do retorno da função anterior
    a = pix[1]
    b = 128
    time.sleep(1)

    if a == b:
     my_function81()

    
    else:
     my_function91()

#execução
loga()
menu()
busca()
my_function4()
loopazul()
loopverde()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-baf19f9b5d20> in <module>
#     296 busca()
#     297 my_function4()
# --> 298 loopazul()
#     299 loopverde()
#     300
#
# <ipython-input-2-baf19f9b5d20> in loopazul()
#     227
#     228     pyautogui.PAUSE = 2.0
# --> 229     pix2 = pyautogui.pixel(74, 395)# coleta a cor da linha da nota buscada
#     230     pyautogui.FAILSAFE = True
#     231     time.sleep(3)
#
# ~\Anaconda3\lib\site-packages\pyscreeze\__init__.py in pixel(x, y)
#     611             bbggrr = "{:0>6x}".format(color) # bbggrr => 'bbggrr' (hex)
#     612             b, g, r = (int(bbggrr[i:i+2], 16) for i in range(0, 6, 2))
# --> 613             return (r, g, b)
#     614     else:
#     615         # Need to select only the first three values of the color in
#
# ~\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#     118         if type is None:
#     119             try:
# --> 120                 next(self.gen)
#     121             except StopIteration:
#     122                 return False
#
# ~\Anaconda3\lib\site-packages\pyscreeze\__init__.py in __win32_openDC(hWnd)
#     120         finally:
#     121             if windll.user32.ReleaseDC(hWnd, hDC) == 0:
# --> 122                 raise WindowsError("windll.user32.ReleaseDC failed : return 0")
#     123
#     124 Box = collections.namedtuple('Box', 'left top width height')
#
# OSError: windll.user32.ReleaseDC failed : return 0

# %% [markdown]
# ## 30092021#        SY - COMPRAS

# %%
import pyautogui
import time

pyautogui.PAUSE = 1

# executa o aplicativo do abacos e faz login
def loga():
    #pyautogui.alert ('Processo cadastro de unidade de negocio será iniciado! ') # exibe mensagem no desktop para inico do programa
    pyautogui.press('winleft') # função que clica no botão windows do mouse 
    time.sleep(1) #tempo de espera para iniciar proxima função
    pyautogui.write('C:\Aplicacao\ABACOS.EXE')  # insere o endereço do executavel do kpl na barra de busca do menu do desktop
    pyautogui.PAUSE = 1.0 #tempo de espera para iniciar proxima função 
    pyautogui.press('enter') #Executa o endereço inserido na busca
    time.sleep(1) #tempo de espera para iniciar proxima função 
    pyautogui.moveTo (672, 672) # digitar no campo que informa o nome do usuário
    pyautogui.write('leandrofer') # função que insere o nome do usuário
    pyautogui.PAUSE = 0.5 #tempo de espera para iniciar proxima inserção
    pyautogui.press('enter') #função que da enter para cursor pular de campoS
    #pyautogui.moveTo (667, 398)
    pyautogui.write('Synapcom2022@@') #função que insere a senha do usuário
    pyautogui.PAUSE = 1.0 #tempo de espera para iniciar proxima inserçãoS
    pyautogui.moveTo (638, 436) # clica no campo de logar
    pyautogui.doubleClick(button='left') # duplo clique na campo de logar
    time.sleep(15) #tempo de espera para finalizar o programa
    #pyautogui.alert ('Logado com sucesso no Abacos!') #Fim do programa
    #time.sleep(30)
    
    
def menu():
    #pyautogui.alert ('Processo de aprovação de notas fiscais será iniciado ')
    time.sleep(7) #aguarda 10 segundos 
    pyautogui.moveTo (67, 637) #clica na barra de busca do menu
    time.sleep(5) #aguarda 1 segundoc
    pyautogui.doubleClick(button='left') #duplo click na barra
    pyautogui.write('digitar') #Digita o atalho
    pyautogui.press('enter') #função que da enter para cursor pular de campo
    pyautogui.moveTo (112, 302) # Point(x=112, y=302)
    pyautogui.doubleClick(button='left')
    time.sleep(4)

def busca(): #busca
    time.sleep = 10
    pyautogui.press('TAB')
    pyautogui.press('TAB')
    pyautogui.press('TAB')
    pyautogui.write('DIGI')
    #pyautogui.press('enter')
    pyautogui.press('TAB')
    pyautogui.press('TAB')
    pyautogui.write('SY - COMPRAS')
    #pyautogui.press('enter')
    pyautogui.press('TAB')
    pyautogui.press('TAB')
    pyautogui.press('TAB')
    pyautogui.write('01082021')
    pyautogui.press('TAB')
    #pyautogui.press('enter')
    pyautogui.write('30092021')
    pyautogui.press('TAB')
    pyautogui.write('282828')
    pyautogui.hotkey('shift', 'enter')
    time.sleep(3)

loga()
menu()
busca()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-6f967f505611> in <module>
#      64 loga()
#      65 menu()
# ---> 66 busca()
#
# <ipython-input-14-6f967f505611> in busca()
#      41 def busca(): #busca
#      42     time.sleep = 10
# ---> 43     pyautogui.press('TAB')
#      44     pyautogui.press('TAB')
#      45     pyautogui.press('TAB')
#
# ~\Anaconda3\lib\site-packages\pyautogui\__init__.py in wrapper(*args, **kwargs)
#     584     def wrapper(*args, **kwargs):
#     585         failSafeCheck()
# --> 586         returnVal = wrappedFunction(*args, **kwargs)
#     587         _handlePause(kwargs.get("_pause", True))
#     588         return returnVal
#
# ~\Anaconda3\lib\site-packages\pyautogui\__init__.py in press(keys, presses, interval, logScreenshot, _pause)
#    1597             platformModule._keyDown(k)
#    1598             platformModule._keyUp(k)
# -> 1599         time.sleep(interval)
#    1600
#    1601
#
# TypeError: 'int' object is not callable
