# %%
import tkinter as tk
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.remote.webelement import WebElement
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import time
from selenium.webdriver.support.select import Select



window = tk.Tk()

window.title("Chave de Davi")

#window.rowconfigure([0, 1, 2, 3] , weight=10)
window.columnconfigure([0, 1, 2, 3, 4] , weight=100)


#window.rowconfigure(0, minsize=50)
#window.columnconfigure([0, 1, 2, 3], minsize=50)


#mensagem = tk.Label(text="SEB", fg='white', bg='black')
#mensagem.grid(row=0, column=0, columnspan=2, sticky="NSEW")



mensagem2 = tk.Label(text="ARNO",fg='white', bg='blue')
mensagem2.grid(row=0, column=0, columnspan=2, sticky="NSEW")
# função de login
def loga():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://www.b2wmarketplace.com.br/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'ds-clickwrap')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/div[1]/input').send_keys("arno_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/div[2]/input').send_keys("Arno@2021" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/p/button').click()

 
botao = tk.Button(text="Arno - B2W" , command=loga)
botao.grid(row=1, column=0, columnspan=2, sticky="NSEW")

def logaa():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://marketplace.integracommerce.com.br")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'kc-logo-magalu')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("arno_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@21" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="kc-login"]').click()

 
botao2 = tk.Button(text="Arno - Magalu" , command=logaa)
botao2.grid(row=2, column=0, columnspan=2, sticky="NSEW")



def logab():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://marketplace-kabum.mirakl.net/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'submitButton')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("arno_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2020*" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()

 
botao3 = tk.Button(text="Arno - Kabum" , command=logab)
botao3.grid(row=3, column=0, columnspan=2, sticky="NSEW")


def logac():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://plataformamarketplaceprd.b2clogin.com/plataformamarketplaceprd.onmicrosoft.com/b2c_1a_signup_signin_pas/oauth2/v2.0/authorize?client_id=07d16b2e-55be-4c02-93c3-6d859ed6ff12&scope=openid%20profile%20offline_access&redirect_uri=https%3A%2F%2Fpas.viavarejo.com.br&client-request-id=fba18cc8-a34a-4981-8fec-841f0f05036c&response_mode=fragment&response_type=code&x-client-SKU=msal.js.browser&x-client-VER=2.14.0&x-client-OS=&x-client-CPU=&client_info=1&code_challenge=ktNQn-TaDzCKYOSqfZ7eagvbwfvORU713iZvKSCPKEo&code_challenge_method=S256&nonce=a8828d49-f1fb-4159-a31f-a9d04f3ea9c2&state=eyJpZCI6IjQ2NmI1MTZiLTEyMDYtNGExMS04ZThiLTA4ZjU1YmU1Y2I5YiIsIm1ldGEiOnsiaW50ZXJhY3Rpb25UeXBlIjoicmVkaXJlY3QifX0%3D")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'api')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="signInName"]').send_keys("arno_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("wdi4Mfg^" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="continue"]').click()

 
botao4 = tk.Button(text="Arno - Via Varejo" , command=logac)
botao4.grid(row=4, column=0, columnspan=2, sticky="NSEW")

def logad():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://leroymerlin.mirakl.net/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'submitButton')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("arno_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2021" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()

 
botaoarno4 = tk.Button(text="Arno - Leroy Merlin" , command=logad)
botaoarno4.grid(row=5, column=0, columnspan=2, sticky="NSEW")


def logae():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://gpa-prod.mirakl.net/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'submitButton')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("arno_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2021" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()

 
botaoarno41 = tk.Button(text="Arno - GPA" , command=logae)
botaoarno41.grid(row=6, column=0, columnspan=2, sticky="NSEW")


def logaf():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://in.skyhub.com.br/users/sign_in#/")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'main-content')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="user_email"]').send_keys("arno_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="user_password"]').send_keys("Synapcom@23" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="new_user"]/fieldset/div[2]/div/input').click()

 
botaoarno15 = tk.Button(text="Arno - Skyhub" , command=logaf)
botaoarno15.grid(row=7, column=0, columnspan=2, sticky="NSEW")



mensagem = tk.Label(text="ROCHEDO",fg='white', bg='blue')
mensagem.grid(row=9, column=0, columnspan=2, sticky="NSEW")
# função de login
def loga1():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://www.b2wmarketplace.com.br/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'ds-clickwrap')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/div[1]/input').send_keys("rochedo_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/div[2]/input').send_keys("Synapcom*21" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/p/button').click()

 
botao11 = tk.Button(text="Rochedo - B2W" , command=loga1)
botao11.grid(row=8, column=0, columnspan=2, sticky="NSEW")


def loga2():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://marketplace.integracommerce.com.br")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'kc-logo-magalu')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("rochedo_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("sTfvy7xf1M" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="kc-login"]').click()

 
botao21 = tk.Button(text="Rochedo - Magalu" , command=loga2)
botao21.grid(row=9, column=0, columnspan=2, sticky="NSEW")



def loga3():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://marketplace-kabum.mirakl.net/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'submitButton')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("rochedo_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2021" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()

 
botao31 = tk.Button(text="Rochedo - Kabum" , command=loga3)
botao31.grid(row=10, column=0, columnspan=2, sticky="NSEW")


def loga4():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://plataformamarketplaceprd.b2clogin.com/plataformamarketplaceprd.onmicrosoft.com/b2c_1a_signup_signin_pas/oauth2/v2.0/authorize?client_id=07d16b2e-55be-4c02-93c3-6d859ed6ff12&scope=openid%20profile%20offline_access&redirect_uri=https%3A%2F%2Fpas.viavarejo.com.br&client-request-id=fba18cc8-a34a-4981-8fec-841f0f05036c&response_mode=fragment&response_type=code&x-client-SKU=msal.js.browser&x-client-VER=2.14.0&x-client-OS=&x-client-CPU=&client_info=1&code_challenge=ktNQn-TaDzCKYOSqfZ7eagvbwfvORU713iZvKSCPKEo&code_challenge_method=S256&nonce=a8828d49-f1fb-4159-a31f-a9d04f3ea9c2&state=eyJpZCI6IjQ2NmI1MTZiLTEyMDYtNGExMS04ZThiLTA4ZjU1YmU1Y2I5YiIsIm1ldGEiOnsiaW50ZXJhY3Rpb25UeXBlIjoicmVkaXJlY3QifX0%3D")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'api')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="signInName"]').send_keys("rochedo_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2021" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="continue"]').click()

 
botao43 = tk.Button(text="Rochedo - Via Varejo" , command=loga4)
botao43.grid(row=11, column=0, columnspan=2, sticky="NSEW")


def loga5():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://leroymerlin.mirakl.net/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'submitButton')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("rochedo_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@21" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()

 
botao42 = tk.Button(text="Rochedo - Leroy Merlin" , command=loga5)
botao42.grid(row=12, column=0, columnspan=2, sticky="NSEW")


def loga6():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://gpa-prod.mirakl.net/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'submitButton')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("rochedo_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Multivarejo@2021" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()

 
botao41 = tk.Button(text="Rochedo - GPA" , command=loga6)
botao41.grid(row=13, column=0, columnspan=2, sticky="NSEW")



def loga47():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://anunciante.zoom.com.br/home")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'login_form')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("synapcom 2" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("fRjfWfhs" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="login_form"]/div[4]/button').click()

 
botao47 = tk.Button(text="Rochedo - ZOOM" , command=loga47)
botao47.grid(row=14, column=0, columnspan=2, sticky="NSEW")


def loga48():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://in.skyhub.com.br/users/sign_in#/")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'main-content')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="user_email"]').send_keys("rochedo_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="user_password"]').send_keys("Synapcom@23" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="new_user"]/fieldset/div[2]/div/input').click()

 
botao48 = tk.Button(text="Rochedo - Skyhub" , command=loga48)
botao48.grid(row=15, column=0, columnspan=2, sticky="NSEW")


mensagem = tk.Label(text="VCG",fg='white', bg='blue')
mensagem.grid(row=18, column=0, columnspan=2, sticky="NSEW")
# função de login
def logavcg1():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://www.b2wmarketplace.com.br/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'ds-clickwrap')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/div[1]/input').send_keys("vcg_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/div[2]/input').send_keys("Synapcom*21" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/p/button').click()

 
botaovcg11 = tk.Button(text="VCG - B2W" , command=logavcg1)
botaovcg11.grid(row=19, column=0, columnspan=2, sticky="NSEW")


def logavcg2():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://marketplace.integracommerce.com.br")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'kc-logo-magalu')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("vcg_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("MU7nSouKpR" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="kc-login"]').click()

 
botaovcg21 = tk.Button(text="VCG - Magalu" , command=logavcg2)
botaovcg21.grid(row=20, column=0, columnspan=2, sticky="NSEW")



def logavcg3():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://marketplace-kabum.mirakl.net/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'submitButton')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("rochedo_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2021" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()

 
botaoVCG31 = tk.Button(text="VCG- Kabum" , command=logavcg3)
botaoVCG31.grid(row=21, column=0, columnspan=2, sticky="NSEW")


def logavcg4():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://plataformamarketplaceprd.b2clogin.com/plataformamarketplaceprd.onmicrosoft.com/b2c_1a_signup_signin_pas/oauth2/v2.0/authorize?client_id=07d16b2e-55be-4c02-93c3-6d859ed6ff12&scope=openid%20profile%20offline_access&redirect_uri=https%3A%2F%2Fpas.viavarejo.com.br&client-request-id=fba18cc8-a34a-4981-8fec-841f0f05036c&response_mode=fragment&response_type=code&x-client-SKU=msal.js.browser&x-client-VER=2.14.0&x-client-OS=&x-client-CPU=&client_info=1&code_challenge=ktNQn-TaDzCKYOSqfZ7eagvbwfvORU713iZvKSCPKEo&code_challenge_method=S256&nonce=a8828d49-f1fb-4159-a31f-a9d04f3ea9c2&state=eyJpZCI6IjQ2NmI1MTZiLTEyMDYtNGExMS04ZThiLTA4ZjU1YmU1Y2I5YiIsIm1ldGEiOnsiaW50ZXJhY3Rpb25UeXBlIjoicmVkaXJlY3QifX0%3D")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'api')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="signInName"]').send_keys("vcg_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("fpe0Qmqs" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="continue"]').click()

 
botaovcg43 = tk.Button(text="VCG - Via Varejo" , command=logavcg4)
botaovcg43.grid(row=22, column=0, columnspan=2, sticky="NSEW")

def logavcg5():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://leroymerlin.mirakl.net/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'submitButton')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("vcg_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@22" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()

 
botaovcg42 = tk.Button(text="VCG - Leroy Merlin" , command=logavcg5)
botaovcg42.grid(row=23, column=0, columnspan=2, sticky="NSEW")


def logavcg6():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://gpa-prod.mirakl.net/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'submitButton')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("vcg_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2022" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()

 
botaovcg41 = tk.Button(text="VCG - GPA" , command=logavcg6)
botaovcg41.grid(row=24, column=0, columnspan=2, sticky="NSEW")



def logavcg47():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://anunciante.zoom.com.br/home")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'login_form')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("vivercasaegourmetparceria" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("n6fGFJg%" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="login_form"]/div[4]/button').click()

 
botaovcg47 = tk.Button(text="VCG - ZOOM" , command=logavcg47)
botaovcg47.grid(row=25, column=0, columnspan=2, sticky="NSEW")

def logavcg48():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://in.skyhub.com.br/users/sign_in#/")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'main-content')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="user_email"]').send_keys("vcg_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="user_password"]').send_keys("Synapcom@23" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="new_user"]/fieldset/div[2]/div/input').click()

 
botaovcg48 = tk.Button(text="VCG - Skyhub" , command=logavcg48)
botaovcg48.grid(row=26, column=0, columnspan=2, sticky="NSEW")


#mensagem = tk.Label(text="Philips", fg='white', bg='black')
#mensagem.grid(row=0, column=2, columnspan=2, sticky="NSEW")


mensagem2 = tk.Label(text="WALLITA",fg='white', bg='blue')
mensagem2.grid(row=1, column=1, columnspan=2, sticky="NSEW")


def logawallita():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://marketplace-kabum.mirakl.net/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'submitButton')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("philipseletro_marketplace2@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2021" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()

 
botaowallita = tk.Button(text="Wallita - Kabum" , command=logawallita)
botaowallita.grid(row=2, column=1, columnspan=2, sticky="NSEW")



def logawallita2():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://plataformamarketplaceprd.b2clogin.com/plataformamarketplaceprd.onmicrosoft.com/b2c_1a_signup_signin_pas/oauth2/v2.0/authorize?client_id=07d16b2e-55be-4c02-93c3-6d859ed6ff12&scope=openid%20profile%20offline_access&redirect_uri=https%3A%2F%2Fpas.viavarejo.com.br&client-request-id=fba18cc8-a34a-4981-8fec-841f0f05036c&response_mode=fragment&response_type=code&x-client-SKU=msal.js.browser&x-client-VER=2.14.0&x-client-OS=&x-client-CPU=&client_info=1&code_challenge=ktNQn-TaDzCKYOSqfZ7eagvbwfvORU713iZvKSCPKEo&code_challenge_method=S256&nonce=a8828d49-f1fb-4159-a31f-a9d04f3ea9c2&state=eyJpZCI6IjQ2NmI1MTZiLTEyMDYtNGExMS04ZThiLTA4ZjU1YmU1Y2I5YiIsIm1ldGEiOnsiaW50ZXJhY3Rpb25UeXBlIjoicmVkaXJlY3QifX0%3D")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'api')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="signInName"]').send_keys("izabelle.cerino@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom21@" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="continue"]').click()

 
botaowallita2 = tk.Button(text="Wallita - Via Varejo" , command=logawallita2)
botaowallita2.grid(row=3, column=1, columnspan=2, sticky="NSEW")


def logawallita3():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://marketplace.integracommerce.com.br")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'kc-logo-magalu')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("vcg_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("MU7nSouKpR" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="kc-login"]').click()

 
botaowallita3 = tk.Button(text="Wallita - Magalu" , command=logawallita3)
botaowallita3.grid(row=4, column=1, columnspan=2, sticky="NSEW")


def logawallita4():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://portal-seller.cloud.carrefour.com.br/signin")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'root')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="root"]/div/div[2]/div/div[2]/div[1]/div[2]/div/button').click()
    time.sleep(5)
    navegador.find_element_by_xpath('//*[@id="email-login"]').send_keys("samara.souza@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Carrefour@2022" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()

 
botaowallita4 = tk.Button(text="Wallita - Carrefour" , command=logawallita4)
botaowallita4.grid(row=5, column=2, columnspan=2, sticky="NSEW")

#mensagem = tk.Label(text="Valdac", fg='white', bg='black')
#mensagem.grid(row=6, column=2, columnspan=2, sticky="NSEW")

mensagem2 = tk.Label(text="Siberian",fg='white', bg='blue')
mensagem2.grid(row=6, column=2, columnspan=2, sticky="NSEW")


def logadafiti():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://sellercenter.com.br/new/user/auth/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'root')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="email"]').send_keys("plinio.vidonscky@valdac.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Valdac@123")
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="recaptcha-anchor"]/div[1]').click()
    #time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="submit"]').click()
    
 
botaodafiti = tk.Button(text="Valdac - Dafiti" , command=logadafiti)
botaodafiti.grid(row=7, column=2, columnspan=2, sticky="NSEW")

#mensagem = tk.Label(text="Tommy Hilfiger", fg='white', bg='black')
#mensagem.grid(row=9, column=2, columnspan=2, sticky="NSEW")

mensagem2 = tk.Label(text="Tommy Hilfiger",fg='white', bg='blue')
mensagem2.grid(row=8, column=2, columnspan=2, sticky="NSEW")

def logavcgtommy():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://in.skyhub.com.br/users/sign_in#/")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'main-content')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="user_email"]').send_keys("tommyhilfiger_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="user_password"]').send_keys("Synapcom@2021" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="new_user"]/fieldset/div[2]/div/input').click()

 
botaologavcgtommy = tk.Button(text="Tommy Hilfiger - Skyhub" , command=logavcgtommy)
botaologavcgtommy.grid(row=9, column=2, columnspan=2, sticky="NSEW")

#mensagem = tk.Label(text="SBD", fg='white', bg='black')
#mensagem.grid(row=12, column=2, columnspan=2, sticky="NSEW")

mensagem2 = tk.Label(text="Dewalt",fg='white', bg='blue')
mensagem2.grid(row=10, column=2, columnspan=2, sticky="NSEW")

def logadewalt():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://plataformamarketplaceprd.b2clogin.com/plataformamarketplaceprd.onmicrosoft.com/b2c_1a_signup_signin_pas/oauth2/v2.0/authorize?client_id=07d16b2e-55be-4c02-93c3-6d859ed6ff12&scope=openid%20profile%20offline_access&redirect_uri=https%3A%2F%2Fpas.viavarejo.com.br&client-request-id=fba18cc8-a34a-4981-8fec-841f0f05036c&response_mode=fragment&response_type=code&x-client-SKU=msal.js.browser&x-client-VER=2.14.0&x-client-OS=&x-client-CPU=&client_info=1&code_challenge=ktNQn-TaDzCKYOSqfZ7eagvbwfvORU713iZvKSCPKEo&code_challenge_method=S256&nonce=a8828d49-f1fb-4159-a31f-a9d04f3ea9c2&state=eyJpZCI6IjQ2NmI1MTZiLTEyMDYtNGExMS04ZThiLTA4ZjU1YmU1Y2I5YiIsIm1ldGEiOnsiaW50ZXJhY3Rpb25UeXBlIjoicmVkaXJlY3QifX0%3D")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'api')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="signInName"]').send_keys("mateus.martins@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Password1!" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="continue"]').click()

 
botaologadewalt = tk.Button(text="Dewalt - Via Varejo" , command=logadewalt)
botaologadewalt.grid(row=11, column=2, columnspan=2, sticky="NSEW")

mensagem2 = tk.Label(text="Black & Decker",fg='white', bg='blue')
mensagem2.grid(row=12, column=2, columnspan=2, sticky="NSEW")

def logablack():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://plataformamarketplaceprd.b2clogin.com/plataformamarketplaceprd.onmicrosoft.com/b2c_1a_signup_signin_pas/oauth2/v2.0/authorize?client_id=07d16b2e-55be-4c02-93c3-6d859ed6ff12&scope=openid%20profile%20offline_access&redirect_uri=https%3A%2F%2Fpas.viavarejo.com.br&client-request-id=fba18cc8-a34a-4981-8fec-841f0f05036c&response_mode=fragment&response_type=code&x-client-SKU=msal.js.browser&x-client-VER=2.14.0&x-client-OS=&x-client-CPU=&client_info=1&code_challenge=ktNQn-TaDzCKYOSqfZ7eagvbwfvORU713iZvKSCPKEo&code_challenge_method=S256&nonce=a8828d49-f1fb-4159-a31f-a9d04f3ea9c2&state=eyJpZCI6IjQ2NmI1MTZiLTEyMDYtNGExMS04ZThiLTA4ZjU1YmU1Y2I5YiIsIm1ldGEiOnsiaW50ZXJhY3Rpb25UeXBlIjoicmVkaXJlY3QifX0%3D")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'api')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="signInName"]').send_keys("mateus.martins@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Password1!" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="continue"]').click()

 
botaologablack = tk.Button(text="Black & Decker - Via Varejo" , command=logablack)
botaologablack.grid(row=13, column=2, columnspan=2, sticky="NSEW")

#mensagem = tk.Label(text="Tigre", fg='white', bg='black')
#mensagem.grid(row=17, column=2, columnspan=2, sticky="NSEW")

mensagem2 = tk.Label(text="Tigre",fg='white', bg='blue')
mensagem2.grid(row=14, column=2, columnspan=2, sticky="NSEW")


def logatigre():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://plataformamarketplaceprd.b2clogin.com/plataformamarketplaceprd.onmicrosoft.com/b2c_1a_signup_signin_pas/oauth2/v2.0/authorize?client_id=07d16b2e-55be-4c02-93c3-6d859ed6ff12&scope=openid%20profile%20offline_access&redirect_uri=https%3A%2F%2Fpas.viavarejo.com.br&client-request-id=fba18cc8-a34a-4981-8fec-841f0f05036c&response_mode=fragment&response_type=code&x-client-SKU=msal.js.browser&x-client-VER=2.14.0&x-client-OS=&x-client-CPU=&client_info=1&code_challenge=ktNQn-TaDzCKYOSqfZ7eagvbwfvORU713iZvKSCPKEo&code_challenge_method=S256&nonce=a8828d49-f1fb-4159-a31f-a9d04f3ea9c2&state=eyJpZCI6IjQ2NmI1MTZiLTEyMDYtNGExMS04ZThiLTA4ZjU1YmU1Y2I5YiIsIm1ldGEiOnsiaW50ZXJhY3Rpb25UeXBlIjoicmVkaXJlY3QifX0%3D")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'api')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="signInName"]').send_keys("micaeli.rocha@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2021" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="continue"]').click()

 
botaologatigre = tk.Button(text="Tigre - Via Varejo" , command=logatigre)
botaologatigre.grid(row=15, column=2, columnspan=2, sticky="NSEW")


def logatigre1():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://www.b2wmarketplace.com.br/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'ds-clickwrap')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/div[1]/input').send_keys("tigremetais_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/div[2]/input').send_keys("Synapcom@2021" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/p/button').click()

 
botaologatigre1 = tk.Button(text="Tigre - B2W" , command=logatigre1)
botaologatigre1.grid(row=16, column=2, columnspan=2, sticky="NSEW")

def logatigre2():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://portal-seller.cloud.carrefour.com.br/signin")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'root')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="root"]/div/div[2]/div/div[2]/div[1]/div[2]/div/button').click()
    time.sleep(5)
    navegador.find_element_by_xpath('//*[@id="email-login"]').send_keys("tigremetais_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Tigreoficial*2022" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()

 
botaologatigre2 = tk.Button(text="Tigre - Carrefour" , command=logatigre2)
botaologatigre2.grid(row=17, column=2, columnspan=2, sticky="NSEW")

def logatigre3():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://leroymerlin.mirakl.net/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'submitButton')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("tigremetais_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2021" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()

 
botaologatigre3 = tk.Button(text="Tigre - Leroy Merlin" , command=logatigre3)
botaologatigre3.grid(row=18, column=2, columnspan=2, sticky="NSEW")

def logatigre4():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://marketplace.integracommerce.com.br")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'kc-logo-magalu')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("tigremetais_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2021" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="kc-login"]').click()

 
botaologatigre4 = tk.Button(text="Tigre - Magalu" , command=logatigre4)
botaologatigre4.grid(row=19, column=2, columnspan=2, sticky="NSEW")

def logatigre5():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://in.skyhub.com.br/users/sign_in#/")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'main-content')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="user_email"]').send_keys("tigremetais_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="user_password"]').send_keys("Synapcom@2021" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="new_user"]/fieldset/div[2]/div/input').click()

 
botaologatigre5 = tk.Button(text="Tigre - Skyhub" , command=logatigre5)
botaologatigre5.grid(row=20, column=2, columnspan=2, sticky="NSEW")


mensagem2 = tk.Label(text="Honeywell",fg='white', bg='blue')
mensagem2.grid(row=21, column=2, columnspan=2, sticky="NSEW")

def logahoneywell():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://portal-seller.cloud.carrefour.com.br/signin")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'root')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="root"]/div/div[2]/div/div[2]/div[1]/div[2]/div/button').click()
    time.sleep(5)
    navegador.find_element_by_xpath('//*[@id="email-login"]').send_keys("honeywell_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("T4!mF0!yN9#28" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()

 
botaologahoneywell = tk.Button(text="Honeywell - Carrefour" , command=logahoneywell)
botaologahoneywell.grid(row=22, column=2, columnspan=2, sticky="NSEW")

def logahoneywell1():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://leroymerlin.mirakl.net/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'submitButton')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("honeywell_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2021" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()

 
botaologahoneywell1 = tk.Button(text="Honeywell - Leroy Merlin" , command=logahoneywell1)
botaologahoneywell1.grid(row=23, column=2, columnspan=2, sticky="NSEW")

def logahoneywell2():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://marketplace.integracommerce.com.br")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'kc-logo-magalu')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("bruna.souza@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("v5xUxAOvCcekzTcoySJT21" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="kc-login"]').click()

 
#botaologahoneywell2 = tk.Button(text="Honeywell - Magalu" , command=logahoneywell2)
#botaologahoneywell2.grid(row=24, column=2, columnspan=2, sticky="NSEW")

def logahoneywell3():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://portalclienteouro.magazineluiza.com.br/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'root')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="E-mail"]').send_keys("honeywell_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="Senha"]').send_keys("mudar123" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="root"]/div/div/div/div[2]/div/div/button').click()

 
#botaologahoneywell3 = tk.Button(text="Honeywell - Magalu Ouro" , command=logahoneywell3)
#botaologahoneywell3.grid(row=25, column=2, columnspan=2, sticky="NSEW")



def logahoneywell4():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://plataformamarketplaceprd.b2clogin.com/plataformamarketplaceprd.onmicrosoft.com/b2c_1a_signup_signin_pas/oauth2/v2.0/authorize?client_id=07d16b2e-55be-4c02-93c3-6d859ed6ff12&scope=openid%20profile%20offline_access&redirect_uri=https%3A%2F%2Fpas.viavarejo.com.br&client-request-id=fba18cc8-a34a-4981-8fec-841f0f05036c&response_mode=fragment&response_type=code&x-client-SKU=msal.js.browser&x-client-VER=2.14.0&x-client-OS=&x-client-CPU=&client_info=1&code_challenge=ktNQn-TaDzCKYOSqfZ7eagvbwfvORU713iZvKSCPKEo&code_challenge_method=S256&nonce=a8828d49-f1fb-4159-a31f-a9d04f3ea9c2&state=eyJpZCI6IjQ2NmI1MTZiLTEyMDYtNGExMS04ZThiLTA4ZjU1YmU1Y2I5YiIsIm1ldGEiOnsiaW50ZXJhY3Rpb25UeXBlIjoicmVkaXJlY3QifX0%3D")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'api')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="signInName"]').send_keys("mateus.martins@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Password1!21" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="continue"]').click()

 
#botaologahoneywell4 = tk.Button(text="Honeywell - Via Varejo" , command=logahoneywell4)
#botaologahoneywell4.grid(row=26, column=2, columnspan=2, sticky="NSEW")



#mensagem22 = tk.Label(text="Tio João",fg='white', bg='blue')
#mensagem22.grid(row=1, column=2, columnspan=2, sticky="NSEW")

def logatiojoao():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://www.b2wmarketplace.com.br/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'ds-clickwrap')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/div[1]/input').send_keys("tiojoao_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/div[2]/input').send_keys("Synapcom@2021" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/p/button').click()

 
botaologatiojoao = tk.Button(text="Tio João - B2W" , command=logatiojoao)
botaologatiojoao.grid(row=2, column=2, columnspan=3, sticky="NSEW")


def logatiojoao1():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://portal-seller.cloud.carrefour.com.br/signin")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'root')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="root"]/div/div[2]/div/div[2]/div[1]/div[2]/div/button').click()
    time.sleep(5)
    navegador.find_element_by_xpath('//*[@id="email-login"]').send_keys("tiojoao_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Armazemjoao@2021" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()

 
#botaologatiojoao1 = tk.Button(text="Tio João - Carrefour" , command=logatiojoao1)
#botaologatiojoao1.grid(row=3, column=2, columnspan=3, sticky="NSEW")

def logatiojoao2():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://gpa-prod.mirakl.net/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'submitButton')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("tiojoao_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Armazemjoao@2021" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()

 
#botaologatiojoao2 = tk.Button(text="Tio João - GPA" , command=logatiojoao2)
#botaologatiojoao2.grid(row=4, column=2, columnspan=3, sticky="NSEW")

def logatiojoao3():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://marketplace.integracommerce.com.br")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'kc-logo-magalu')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("tiojoao_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("83a8f80O78" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="kc-login"]').click()

 
#botaologatiojoao3 = tk.Button(text="Tio João - Magalu" , command=logatiojoao3)
#botaologatiojoao3.grid(row=5, column=2, columnspan=3, sticky="NSEW")

def logatigre5():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://in.skyhub.com.br/users/sign_in#/")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'main-content')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="user_email"]').send_keys("tigremetais_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="user_password"]').send_keys("Synapcom@2021" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="new_user"]/fieldset/div[2]/div/input').click()

 
#botaologatiojoao4 = tk.Button(text="Tio João - Skyhub" , command=logatigre5)
#botaologatiojoao4.grid(row=6, column=2, columnspan=3, sticky="NSEW")

def logahoneywell4():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://plataformamarketplaceprd.b2clogin.com/plataformamarketplaceprd.onmicrosoft.com/b2c_1a_signup_signin_pas/oauth2/v2.0/authorize?client_id=07d16b2e-55be-4c02-93c3-6d859ed6ff12&scope=openid%20profile%20offline_access&redirect_uri=https%3A%2F%2Fpas.viavarejo.com.br&client-request-id=fba18cc8-a34a-4981-8fec-841f0f05036c&response_mode=fragment&response_type=code&x-client-SKU=msal.js.browser&x-client-VER=2.14.0&x-client-OS=&x-client-CPU=&client_info=1&code_challenge=ktNQn-TaDzCKYOSqfZ7eagvbwfvORU713iZvKSCPKEo&code_challenge_method=S256&nonce=a8828d49-f1fb-4159-a31f-a9d04f3ea9c2&state=eyJpZCI6IjQ2NmI1MTZiLTEyMDYtNGExMS04ZThiLTA4ZjU1YmU1Y2I5YiIsIm1ldGEiOnsiaW50ZXJhY3Rpb25UeXBlIjoicmVkaXJlY3QifX0%3D")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'api')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="signInName"]').send_keys("mateus.martins@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Password1!21" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="continue"]').click()

 
#botaologahoneywell4 = tk.Button(text="Honeywell - Via Varejo" , command=logahoneywell4)
#botaologahoneywell4.grid(row=7, column=2, columnspan=3, sticky="NSEW")


#mensagem21 = tk.Label(text="Hummel",fg='white', bg='blue')
#mensagem21.grid(row=1, column=3, columnspan=2, sticky="NSEW")

#mensagem23 = tk.Label(text="WALLITAdfg",fg='white', bg='blue')
#mensagem23.grid(row=1, column=5, columnspan=2, sticky="NSEW")

#mensagem24 = tk.Label(text="WALLITAsdfg",fg='white', bg='blue')
#mensagem24.grid(row=1, column=6, columnspan=2, sticky="NSEW")

window.mainloop()

# %%
import tkinter as tk
from tkinter.filedialog import askopenfilename, asksaveasfilename

def open_file():
    """Open a file for editing."""
    filepath = askopenfilename(
        filetypes=[("Text Files", "*.txt"), ("All Files", "*.*")]
    )
    if not filepath:
        return
    txt_edit.delete(1.0, tk.END)
    with open(filepath, "r") as input_file:
        text = input_file.read()
        txt_edit.insert(tk.END, text)
    window.title(f"Simple Text Editor - {filepath}")

def save_file():
    """Save the current file as a new file."""
    filepath = asksaveasfilename(
        defaultextension="txt",
        filetypes=[("Text Files", "*.txt"), ("All Files", "*.*")],
    )
    if not filepath:
        return
    with open(filepath, "w") as output_file:
        text = txt_edit.get(1.0, tk.END)
        output_file.write(text)
    window.title(f"Simple Text Editor - {filepath}")

window = tk.Tk()
window.title("Simple Text Editor")
window.rowconfigure(0, minsize=800, weight=1)
window.columnconfigure(1, minsize=800, weight=1)

txt_edit = tk.Text(window)
fr_buttons = tk.Frame(window, relief=tk.RAISED, bd=2)
btn_open = tk.Button(fr_buttons, text="Open", command=open_file)
btn_save = tk.Button(fr_buttons, text="Save As...", command=save_file)

btn_open.grid(row=0, column=0, sticky="ew", padx=5, pady=5)
btn_save.grid(row=1, column=0, sticky="ew", padx=5)

fr_buttons.grid(row=0, column=0, sticky="ns")
txt_edit.grid(row=0, column=1, sticky="nsew")

window.mainloop()
