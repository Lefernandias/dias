# %%
import tkinter as tk
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.remote.webelement import WebElement
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import time
from selenium.webdriver.support.select import Select



window = tk.Tk()

window.title("Chave de Davi")

#window.rowconfigure([0, 1, 2, 3] , weight=10)
window.columnconfigure([0, 1, 2, 3, 4, 5, 6, 7, 8] , weight=1)


def logaarno():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://www.b2wmarketplace.com.br/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'ds-clickwrap')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/div[1]/input').send_keys("arno_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/div[2]/input').send_keys("Arno@2021" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/p/button').click()
    
def logaarno2():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://marketplace.integracommerce.com.br")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'kc-logo-magalu')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("arno_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@21" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="kc-login"]').click()
    
    
def logaarno3():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://marketplace-kabum.mirakl.net/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'submitButton')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("arno_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2020*" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()
    
def logaarno4():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://plataformamarketplaceprd.b2clogin.com/plataformamarketplaceprd.onmicrosoft.com/b2c_1a_signup_signin_pas/oauth2/v2.0/authorize?client_id=07d16b2e-55be-4c02-93c3-6d859ed6ff12&scope=openid%20profile%20offline_access&redirect_uri=https%3A%2F%2Fpas.viavarejo.com.br&client-request-id=fba18cc8-a34a-4981-8fec-841f0f05036c&response_mode=fragment&response_type=code&x-client-SKU=msal.js.browser&x-client-VER=2.14.0&x-client-OS=&x-client-CPU=&client_info=1&code_challenge=ktNQn-TaDzCKYOSqfZ7eagvbwfvORU713iZvKSCPKEo&code_challenge_method=S256&nonce=a8828d49-f1fb-4159-a31f-a9d04f3ea9c2&state=eyJpZCI6IjQ2NmI1MTZiLTEyMDYtNGExMS04ZThiLTA4ZjU1YmU1Y2I5YiIsIm1ldGEiOnsiaW50ZXJhY3Rpb25UeXBlIjoicmVkaXJlY3QifX0%3D")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'api')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="signInName"]').send_keys("arno_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("wdi4Mfg^" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="continue"]').click()
    
    
def logaarno5():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://leroymerlin.mirakl.net/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'submitButton')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("arno_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2021" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()
    
def logaarno6():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://gpa-prod.mirakl.net/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'submitButton')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("arno_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2021" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()
    
def logaarno7():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://in.skyhub.com.br/users/sign_in#/")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'main-content')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="user_email"]').send_keys("arno_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="user_password"]').send_keys("Synapcom@23" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="new_user"]/fieldset/div[2]/div/input').click()
    
def logarochedo():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://www.b2wmarketplace.com.br/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'ds-clickwrap')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/div[1]/input').send_keys("rochedo_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/div[2]/input').send_keys("Synapcom*21" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/p/button').click()
    
def logarochedo2():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://marketplace.integracommerce.com.br")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'kc-logo-magalu')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("rochedo_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("sTfvy7xf1M" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="kc-login"]').click()
    
def logarochedo3():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://marketplace-kabum.mirakl.net/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'submitButton')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("rochedo_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2021" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()
    
def logarochedo4():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://plataformamarketplaceprd.b2clogin.com/plataformamarketplaceprd.onmicrosoft.com/b2c_1a_signup_signin_pas/oauth2/v2.0/authorize?client_id=07d16b2e-55be-4c02-93c3-6d859ed6ff12&scope=openid%20profile%20offline_access&redirect_uri=https%3A%2F%2Fpas.viavarejo.com.br&client-request-id=fba18cc8-a34a-4981-8fec-841f0f05036c&response_mode=fragment&response_type=code&x-client-SKU=msal.js.browser&x-client-VER=2.14.0&x-client-OS=&x-client-CPU=&client_info=1&code_challenge=ktNQn-TaDzCKYOSqfZ7eagvbwfvORU713iZvKSCPKEo&code_challenge_method=S256&nonce=a8828d49-f1fb-4159-a31f-a9d04f3ea9c2&state=eyJpZCI6IjQ2NmI1MTZiLTEyMDYtNGExMS04ZThiLTA4ZjU1YmU1Y2I5YiIsIm1ldGEiOnsiaW50ZXJhY3Rpb25UeXBlIjoicmVkaXJlY3QifX0%3D")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'api')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="signInName"]').send_keys("rochedo_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2021" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="continue"]').click()
    
    
def logarochedo5():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://leroymerlin.mirakl.net/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'submitButton')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("rochedo_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@21" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()
    
def logarochedo6():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://gpa-prod.mirakl.net/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'submitButton')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("rochedo_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Multivarejo@2021" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()
    
def logarochedo7():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://anunciante.zoom.com.br/home")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'login_form')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("synapcom 2" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("fRjfWfhs" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="login_form"]/div[4]/button').click()
    
def logarochedo8():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://in.skyhub.com.br/users/sign_in#/")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'main-content')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="user_email"]').send_keys("rochedo_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="user_password"]').send_keys("Synapcom@23" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="new_user"]/fieldset/div[2]/div/input').click()
    
    
def logavcg():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://www.b2wmarketplace.com.br/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'ds-clickwrap')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/div[1]/input').send_keys("vcg_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/div[2]/input').send_keys("Synapcom*21" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/p/button').click()
    
def logavcg2():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://marketplace.integracommerce.com.br")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'kc-logo-magalu')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("vcg_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("MU7nSouKpR" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="kc-login"]').click()
    
def logavcg3():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://marketplace-kabum.mirakl.net/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'submitButton')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("rochedo_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2021" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()
    
def logavcg4():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://plataformamarketplaceprd.b2clogin.com/plataformamarketplaceprd.onmicrosoft.com/b2c_1a_signup_signin_pas/oauth2/v2.0/authorize?client_id=07d16b2e-55be-4c02-93c3-6d859ed6ff12&scope=openid%20profile%20offline_access&redirect_uri=https%3A%2F%2Fpas.viavarejo.com.br&client-request-id=fba18cc8-a34a-4981-8fec-841f0f05036c&response_mode=fragment&response_type=code&x-client-SKU=msal.js.browser&x-client-VER=2.14.0&x-client-OS=&x-client-CPU=&client_info=1&code_challenge=ktNQn-TaDzCKYOSqfZ7eagvbwfvORU713iZvKSCPKEo&code_challenge_method=S256&nonce=a8828d49-f1fb-4159-a31f-a9d04f3ea9c2&state=eyJpZCI6IjQ2NmI1MTZiLTEyMDYtNGExMS04ZThiLTA4ZjU1YmU1Y2I5YiIsIm1ldGEiOnsiaW50ZXJhY3Rpb25UeXBlIjoicmVkaXJlY3QifX0%3D")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'api')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="signInName"]').send_keys("vcg_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("fpe0Qmqs" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="continue"]').click()

def logavcg5():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://leroymerlin.mirakl.net/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'submitButton')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("vcg_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@22" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()
    
def logavcg6():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://gpa-prod.mirakl.net/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'submitButton')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("vcg_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2022" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()

def logavcg7():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://anunciante.zoom.com.br/home")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'login_form')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("vivercasaegourmetparceria" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("n6fGFJg%" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="login_form"]/div[4]/button').click()
    
def logavcg8():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://in.skyhub.com.br/users/sign_in#/")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'main-content')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="user_email"]').send_keys("vcg_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="user_password"]').send_keys("Synapcom@23" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="new_user"]/fieldset/div[2]/div/input').click()
    
def logawallita():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://marketplace-kabum.mirakl.net/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'submitButton')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("philipseletro_marketplace2@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2021" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()
    
def logawallita2():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://plataformamarketplaceprd.b2clogin.com/plataformamarketplaceprd.onmicrosoft.com/b2c_1a_signup_signin_pas/oauth2/v2.0/authorize?client_id=07d16b2e-55be-4c02-93c3-6d859ed6ff12&scope=openid%20profile%20offline_access&redirect_uri=https%3A%2F%2Fpas.viavarejo.com.br&client-request-id=fba18cc8-a34a-4981-8fec-841f0f05036c&response_mode=fragment&response_type=code&x-client-SKU=msal.js.browser&x-client-VER=2.14.0&x-client-OS=&x-client-CPU=&client_info=1&code_challenge=ktNQn-TaDzCKYOSqfZ7eagvbwfvORU713iZvKSCPKEo&code_challenge_method=S256&nonce=a8828d49-f1fb-4159-a31f-a9d04f3ea9c2&state=eyJpZCI6IjQ2NmI1MTZiLTEyMDYtNGExMS04ZThiLTA4ZjU1YmU1Y2I5YiIsIm1ldGEiOnsiaW50ZXJhY3Rpb25UeXBlIjoicmVkaXJlY3QifX0%3D")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'api')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="signInName"]').send_keys("izabelle.cerino@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom21@" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="continue"]').click()
    
def logawallita3():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://marketplace.integracommerce.com.br")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'kc-logo-magalu')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("vcg_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("MU7nSouKpR" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="kc-login"]').click()
    
def logawallita4():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://portal-seller.cloud.carrefour.com.br/signin")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'root')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="root"]/div/div[2]/div/div[2]/div[1]/div[2]/div/button').click()
    time.sleep(5)
    navegador.find_element_by_xpath('//*[@id="email-login"]').send_keys("samara.souza@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Carrefour@2022" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()
    
def logadavaldac():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://sellercenter.com.br/new/user/auth/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'root')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="email"]').send_keys("plinio.vidonscky@valdac.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Valdac@123")
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="recaptcha-anchor"]/div[1]').click()
    #time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="submit"]').click()
    
def logatommy():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://in.skyhub.com.br/users/sign_in#/")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'main-content')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="user_email"]').send_keys("tommyhilfiger_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="user_password"]').send_keys("Synapcom@2021" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="new_user"]/fieldset/div[2]/div/input').click()
    
def logadewalt():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://plataformamarketplaceprd.b2clogin.com/plataformamarketplaceprd.onmicrosoft.com/b2c_1a_signup_signin_pas/oauth2/v2.0/authorize?client_id=07d16b2e-55be-4c02-93c3-6d859ed6ff12&scope=openid%20profile%20offline_access&redirect_uri=https%3A%2F%2Fpas.viavarejo.com.br&client-request-id=fba18cc8-a34a-4981-8fec-841f0f05036c&response_mode=fragment&response_type=code&x-client-SKU=msal.js.browser&x-client-VER=2.14.0&x-client-OS=&x-client-CPU=&client_info=1&code_challenge=ktNQn-TaDzCKYOSqfZ7eagvbwfvORU713iZvKSCPKEo&code_challenge_method=S256&nonce=a8828d49-f1fb-4159-a31f-a9d04f3ea9c2&state=eyJpZCI6IjQ2NmI1MTZiLTEyMDYtNGExMS04ZThiLTA4ZjU1YmU1Y2I5YiIsIm1ldGEiOnsiaW50ZXJhY3Rpb25UeXBlIjoicmVkaXJlY3QifX0%3D")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'api')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="signInName"]').send_keys("mateus.martins@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Password1!" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="continue"]').click()
    
def logablack():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://plataformamarketplaceprd.b2clogin.com/plataformamarketplaceprd.onmicrosoft.com/b2c_1a_signup_signin_pas/oauth2/v2.0/authorize?client_id=07d16b2e-55be-4c02-93c3-6d859ed6ff12&scope=openid%20profile%20offline_access&redirect_uri=https%3A%2F%2Fpas.viavarejo.com.br&client-request-id=fba18cc8-a34a-4981-8fec-841f0f05036c&response_mode=fragment&response_type=code&x-client-SKU=msal.js.browser&x-client-VER=2.14.0&x-client-OS=&x-client-CPU=&client_info=1&code_challenge=ktNQn-TaDzCKYOSqfZ7eagvbwfvORU713iZvKSCPKEo&code_challenge_method=S256&nonce=a8828d49-f1fb-4159-a31f-a9d04f3ea9c2&state=eyJpZCI6IjQ2NmI1MTZiLTEyMDYtNGExMS04ZThiLTA4ZjU1YmU1Y2I5YiIsIm1ldGEiOnsiaW50ZXJhY3Rpb25UeXBlIjoicmVkaXJlY3QifX0%3D")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'api')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="signInName"]').send_keys("mateus.martins@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Password1!" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="continue"]').click()
    
    
def logatigre():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://plataformamarketplaceprd.b2clogin.com/plataformamarketplaceprd.onmicrosoft.com/b2c_1a_signup_signin_pas/oauth2/v2.0/authorize?client_id=07d16b2e-55be-4c02-93c3-6d859ed6ff12&scope=openid%20profile%20offline_access&redirect_uri=https%3A%2F%2Fpas.viavarejo.com.br&client-request-id=fba18cc8-a34a-4981-8fec-841f0f05036c&response_mode=fragment&response_type=code&x-client-SKU=msal.js.browser&x-client-VER=2.14.0&x-client-OS=&x-client-CPU=&client_info=1&code_challenge=ktNQn-TaDzCKYOSqfZ7eagvbwfvORU713iZvKSCPKEo&code_challenge_method=S256&nonce=a8828d49-f1fb-4159-a31f-a9d04f3ea9c2&state=eyJpZCI6IjQ2NmI1MTZiLTEyMDYtNGExMS04ZThiLTA4ZjU1YmU1Y2I5YiIsIm1ldGEiOnsiaW50ZXJhY3Rpb25UeXBlIjoicmVkaXJlY3QifX0%3D")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'api')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="signInName"]').send_keys("micaeli.rocha@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2021" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="continue"]').click()
    
def logatigre1():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://www.b2wmarketplace.com.br/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'ds-clickwrap')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/div[1]/input').send_keys("tigremetais_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/div[2]/input').send_keys("Synapcom@2021" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/p/button').click()
    
def logatigre2():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://portal-seller.cloud.carrefour.com.br/signin")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'root')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="root"]/div/div[2]/div/div[2]/div[1]/div[2]/div/button').click()
    time.sleep(5)
    navegador.find_element_by_xpath('//*[@id="email-login"]').send_keys("tigremetais_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Tigreoficial*2022" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()

def logatigre3():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://leroymerlin.mirakl.net/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'submitButton')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("tigremetais_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2021" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()
    
def logatigre4():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://marketplace.integracommerce.com.br")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'kc-logo-magalu')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("tigremetais_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2021" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="kc-login"]').click()

def logatigre5():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://in.skyhub.com.br/users/sign_in#/")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'main-content')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="user_email"]').send_keys("tigremetais_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="user_password"]').send_keys("Synapcom@2021" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="new_user"]/fieldset/div[2]/div/input').click()
    
def logahoneywell():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://portal-seller.cloud.carrefour.com.br/signin")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'root')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="root"]/div/div[2]/div/div[2]/div[1]/div[2]/div/button').click()
    time.sleep(5)
    navegador.find_element_by_xpath('//*[@id="email-login"]').send_keys("honeywell_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("T4!mF0!yN9#28" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()
    
def logahoneywell1():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://portal-seller.cloud.carrefour.com.br/signin")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'root')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="root"]/div/div[2]/div/div[2]/div[1]/div[2]/div/button').click()
    time.sleep(5)
    navegador.find_element_by_xpath('//*[@id="email-login"]').send_keys("honeywell_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("T4!mF0!yN9#28" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()
    
def logahoneywell2():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://leroymerlin.mirakl.net/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'submitButton')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("honeywell_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2021" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()
    
def logahoneywell3():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://marketplace.integracommerce.com.br")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'kc-logo-magalu')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("bruna.souza@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("v5xUxAOvCcekzTcoySJT21" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="kc-login"]').click()
    
    
def logahoneywell4():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://portalclienteouro.magazineluiza.com.br/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'root')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="E-mail"]').send_keys("honeywell_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="Senha"]').send_keys("mudar123" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="root"]/div/div/div/div[2]/div/div/button').click()
    
def logahoneywell5():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://plataformamarketplaceprd.b2clogin.com/plataformamarketplaceprd.onmicrosoft.com/b2c_1a_signup_signin_pas/oauth2/v2.0/authorize?client_id=07d16b2e-55be-4c02-93c3-6d859ed6ff12&scope=openid%20profile%20offline_access&redirect_uri=https%3A%2F%2Fpas.viavarejo.com.br&client-request-id=fba18cc8-a34a-4981-8fec-841f0f05036c&response_mode=fragment&response_type=code&x-client-SKU=msal.js.browser&x-client-VER=2.14.0&x-client-OS=&x-client-CPU=&client_info=1&code_challenge=ktNQn-TaDzCKYOSqfZ7eagvbwfvORU713iZvKSCPKEo&code_challenge_method=S256&nonce=a8828d49-f1fb-4159-a31f-a9d04f3ea9c2&state=eyJpZCI6IjQ2NmI1MTZiLTEyMDYtNGExMS04ZThiLTA4ZjU1YmU1Y2I5YiIsIm1ldGEiOnsiaW50ZXJhY3Rpb25UeXBlIjoicmVkaXJlY3QifX0%3D")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'api')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="signInName"]').send_keys("mateus.martins@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Password1!21" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="continue"]').click()
    
def logahoneywell6():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://plataformamarketplaceprd.b2clogin.com/plataformamarketplaceprd.onmicrosoft.com/b2c_1a_signup_signin_pas/oauth2/v2.0/authorize?client_id=07d16b2e-55be-4c02-93c3-6d859ed6ff12&scope=openid%20profile%20offline_access&redirect_uri=https%3A%2F%2Fpas.viavarejo.com.br&client-request-id=fba18cc8-a34a-4981-8fec-841f0f05036c&response_mode=fragment&response_type=code&x-client-SKU=msal.js.browser&x-client-VER=2.14.0&x-client-OS=&x-client-CPU=&client_info=1&code_challenge=ktNQn-TaDzCKYOSqfZ7eagvbwfvORU713iZvKSCPKEo&code_challenge_method=S256&nonce=a8828d49-f1fb-4159-a31f-a9d04f3ea9c2&state=eyJpZCI6IjQ2NmI1MTZiLTEyMDYtNGExMS04ZThiLTA4ZjU1YmU1Y2I5YiIsIm1ldGEiOnsiaW50ZXJhY3Rpb25UeXBlIjoicmVkaXJlY3QifX0%3D")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'api')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="signInName"]').send_keys("mateus.martins@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Password1!21" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="continue"]').click()
#B2W    
def logatiojoao():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://www.b2wmarketplace.com.br/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'ds-clickwrap')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/div[1]/input').send_keys("tiojoao_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/div[2]/input').send_keys("Synapcom@2021" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/p/button').click()

    
#carrefour

def logatiojoao2():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://portal-seller.cloud.carrefour.com.br/signin")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'root')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="root"]/div/div[2]/div/div[2]/div[1]/div[2]/div/button').click()
    time.sleep(5)
    navegador.find_element_by_xpath('//*[@id="email-login"]').send_keys("tiojoao_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Armazemjoao@2021" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()
    
#GPA   
def logatiojoao3():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://gpa-prod.mirakl.net/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'submitButton')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("tiojoao_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Armazemjoao@2021" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()

#magalu    
def logatiojoao4():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://marketplace.integracommerce.com.br")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'kc-logo-magalu')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("tiojoao_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("83a8f80O78" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="kc-login"]').click()

#skyhub    
def logatiojoao5():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://in.skyhub.com.br/users/sign_in#/")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'main-content')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="user_email"]').send_keys("tiojoao_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="user_password"]').send_keys("Synapcom@2021" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="new_user"]/fieldset/div[2]/div/input').click()
    
#via Varejo    
def logatiojoao6():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://plataformamarketplaceprd.b2clogin.com/plataformamarketplaceprd.onmicrosoft.com/b2c_1a_signup_signin_pas/oauth2/v2.0/authorize?client_id=07d16b2e-55be-4c02-93c3-6d859ed6ff12&scope=openid%20profile%20offline_access&redirect_uri=https%3A%2F%2Fpas.viavarejo.com.br&client-request-id=fba18cc8-a34a-4981-8fec-841f0f05036c&response_mode=fragment&response_type=code&x-client-SKU=msal.js.browser&x-client-VER=2.14.0&x-client-OS=&x-client-CPU=&client_info=1&code_challenge=ktNQn-TaDzCKYOSqfZ7eagvbwfvORU713iZvKSCPKEo&code_challenge_method=S256&nonce=a8828d49-f1fb-4159-a31f-a9d04f3ea9c2&state=eyJpZCI6IjQ2NmI1MTZiLTEyMDYtNGExMS04ZThiLTA4ZjU1YmU1Y2I5YiIsIm1ldGEiOnsiaW50ZXJhY3Rpb25UeXBlIjoicmVkaXJlY3QifX0%3D")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'api')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="signInName"]').send_keys("tiojoao_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2021" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="continue"]').click()

#Droga Raia     
def logatiojoao7():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://www.lojistard.com.br/SignIn?returnUrl=%2F")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'local-login-heading')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="Username"]').send_keys("atd.synapcom" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="PasswordValue"]').send_keys("Synapcom@21" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="submit-signin-local"]').click()
    
#carrefour   
def logasolutions2go():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://portal-seller.cloud.carrefour.com.br/signin")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'root')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="root"]/div/div[2]/div/div[2]/div[1]/div[2]/div/button').click()
    time.sleep(5)
    navegador.find_element_by_xpath('//*[@id="email-login"]').send_keys("glauco.bueno@solutions2gobr.com" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2021" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()
    

#Bom de Beer   
#B2W    
def logabomdebeer():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://www.b2wmarketplace.com.br/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'ds-clickwrap')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/div[1]/input').send_keys("bombeer_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/div[2]/input').send_keys("Synapcom@22" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/p/button').click()
    
    
    
#carrefour   
def logabomdebeer2():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://portal-seller.cloud.carrefour.com.br/signin")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'root')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="root"]/div/div[2]/div/div[2]/div[1]/div[2]/div/button').click()
    time.sleep(5)
    navegador.find_element_by_xpath('//*[@id="email-login"]').send_keys("bombeer_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("O2!dZ3?sX3" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()
    
    
    
#GPA   
def logabomdebeer3():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://gpa-prod.mirakl.net/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'submitButton')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("bombeer_marketplace@synapcom.com.br" + Keys.ENTER)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Multivarejo@2021" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="signInSubmit"]').click()
    
    
    
#magalu    
def logabomdebeer4():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://marketplace.integracommerce.com.br")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'kc-logo-magalu')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("bombeer_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2021" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="kc-login"]').click()
    
    
    
#via Varejo    
def logabomdebeer5():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://plataformamarketplaceprd.b2clogin.com/plataformamarketplaceprd.onmicrosoft.com/b2c_1a_signup_signin_pas/oauth2/v2.0/authorize?client_id=07d16b2e-55be-4c02-93c3-6d859ed6ff12&scope=openid%20profile%20offline_access&redirect_uri=https%3A%2F%2Fpas.viavarejo.com.br&client-request-id=fba18cc8-a34a-4981-8fec-841f0f05036c&response_mode=fragment&response_type=code&x-client-SKU=msal.js.browser&x-client-VER=2.14.0&x-client-OS=&x-client-CPU=&client_info=1&code_challenge=ktNQn-TaDzCKYOSqfZ7eagvbwfvORU713iZvKSCPKEo&code_challenge_method=S256&nonce=a8828d49-f1fb-4159-a31f-a9d04f3ea9c2&state=eyJpZCI6IjQ2NmI1MTZiLTEyMDYtNGExMS04ZThiLTA4ZjU1YmU1Y2I5YiIsIm1ldGEiOnsiaW50ZXJhY3Rpb25UeXBlIjoicmVkaXJlY3QifX0%3D")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'api')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="signInName"]').send_keys("bomdebeer_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2021" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="continue"]').click()
    
    
#skyhub    
def logabomdebeer6():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://in.skyhub.com.br/users/sign_in#/")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'main-content')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="user_email"]').send_keys("bombeer_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="user_password"]').send_keys("Synapcom@2021" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="new_user"]/fieldset/div[2]/div/input').click()
    
    
    
#Droga Raia     
def logabomdebeer7():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://www.lojistard.com.br/SignIn?returnUrl=%2F")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'local-login-heading')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="Username"]').send_keys("atd.synapcom" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="PasswordValue"]').send_keys("Synapcom@21" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="submit-signin-local"]').click()
    
#Riachuelo    
def logabomdebeer8():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://marketplace.riachuelo.com.br/")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'kc-content')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("natalia.cheapetta@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom21!" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="kc-login"]').click()

#Brandili
#B2W
def logabrandili():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://www.b2wmarketplace.com.br/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'ds-clickwrap')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/div[1]/input').send_keys("B2W_PARCEIRO_27932734002665" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/div[2]/input').send_keys("Synapcom@19" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[1]/div[1]/form/p/button').click()



#Dafiti
def logabrandili2():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://sellercenter.com.br/new/user/auth/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'root')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="email"]').send_keys("marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@21")
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="recaptcha-anchor"]/div[1]').click()
    #time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="submit"]').click()


#Magalu
def logabrandili3():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://marketplace.integracommerce.com.br")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'kc-logo-magalu')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("brandili_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom@2021" + Keys.ENTER)
    time.sleep(2)
    #navegador.find_element_by_xpath('//*[@id="kc-login"]').click()



#Ri Happy
def logabrandili4():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://seller.gruporihappy.com.br/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'checkbox-input')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('/html/body/core-root/div/div/app-login/div/form/div[3]/div/input[1]').send_keys("brandili" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('/html/body/core-root/div/div/app-login/div/form/div[3]/div/input[2]').send_keys("sellerrhsc2021" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('/html/body/core-root/div/div/app-login/div/form/div[4]/button').click()

#Skyhub
def logabrandili5():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://in.skyhub.com.br/users/sign_in#/")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'main-content')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="user_email"]').send_keys("brandili_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="user_password"]').send_keys("Synapcom@19" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="new_user"]/fieldset/div[2]/div/input').click()


#Riachuelo
def logabrandili6():
    navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")
    navegador.get("https://marketplace.riachuelo.com.br/")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'kc-content')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="username"]').send_keys("natalia.cheapetta@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="password"]').send_keys("Synapcom21!" + Keys.TAB)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="kc-login"]').click()

    
# formação da grade de botões
mensagemarno = tk.Label(text="Arno",fg='white', bg='blue')
mensagemarno.grid(row=0, column=0, columnspan=1)
    
botaologaarno = tk.Button(text="Arno - B2W" , command=logaarno)
botaologaarno.grid(row=1, column=0, columnspan=1)

botaologaarno2 = tk.Button(text="Arno - Magalu" , command=logaarno2)
botaologaarno2.grid(row=2, column=0, columnspan=1)

botaologaarno3 = tk.Button(text="Arno - Kabum" , command=logaarno3)
botaologaarno3.grid(row=3, column=0, columnspan=1)

botaologaarno4 = tk.Button(text="Arno - Via Varejo" , command=logaarno4)
botaologaarno4.grid(row=4, column=0, columnspan=1)

botaologaarno5 = tk.Button(text="Arno - Leroy Merlin" , command=logaarno5)
botaologaarno5.grid(row=5, column=0, columnspan=1)

botaologaarno6 = tk.Button(text="Arno - GPA" , command=logaarno6)
botaologaarno6.grid(row=6, column=0, columnspan=1)

botaologaarno7 = tk.Button(text="Arno - Skyhub" , command=logaarno7)
botaologaarno7.grid(row=7, column=0, columnspan=1)

mensagemrochedo = tk.Label(text="Rochedo",fg='white', bg='blue')
mensagemrochedo.grid(row=8, column=0, columnspan=1)

botaologarochedo = tk.Button(text="Rochedo - B2W" , command=logarochedo)
botaologarochedo.grid(row=9, column=0, columnspan=1)

botaologarochedo2 = tk.Button(text="Rochedo - Magalu" , command=logarochedo2)
botaologarochedo2.grid(row=10, column=0, columnspan=1)

botaologarochedo3 = tk.Button(text="Rochedo - Kabum" , command=logarochedo3)
botaologarochedo3.grid(row=11, column=0, columnspan=1)

botaologarochedo4 = tk.Button(text="Rochedo - Via Varejo" , command=logarochedo4)
botaologarochedo4.grid(row=12, column=0, columnspan=1)

botaologarochedo5 = tk.Button(text="Rochedo - Leroy Merlin" , command=logarochedo5)
botaologarochedo5.grid(row=13, column=0, columnspan=1)

botaologarochedo6 = tk.Button(text="Rochedo - GPA" , command=logarochedo6)
botaologarochedo6.grid(row=14, column=0, columnspan=1)

botaologarochedo7 = tk.Button(text="Rochedo - ZOOM" , command=logarochedo7)
botaologarochedo7.grid(row=15, column=0, columnspan=1)

botaologarochedo8 = tk.Button(text="Rochedo - Skyhub" , command=logarochedo8)
botaologarochedo8.grid(row=16, column=0, columnspan=1)

mensagemvcg = tk.Label(text="vcg",fg='white', bg='blue')
mensagemvcg.grid(row=17, column=0, columnspan=1)

botaologavcg = tk.Button(text="vcg - B2W" , command=logavcg)
botaologavcg.grid(row=18, column=0, columnspan=1)

botaologavcg2 = tk.Button(text="vcg - Magalu" , command=logavcg2)
botaologavcg2.grid(row=19, column=0, columnspan=1)

botaologavcg3 = tk.Button(text="vcg- Kabum" , command=logavcg3)
botaologavcg3.grid(row=20, column=0, columnspan=1)

botaologavcg4 = tk.Button(text="vcg - Via Varejo" , command=logavcg4)
botaologavcg4.grid(row=21, column=0, columnspan=1)

botaologavcg5 = tk.Button(text="vcg - Leroy Merlin" , command=logavcg5)
botaologavcg5.grid(row=22, column=0, columnspan=1)

botaologavcg6 = tk.Button(text="vcg - GPA" , command=logavcg6)
botaologavcg6.grid(row=23, column=0, columnspan=1)

botaologavcg7 = tk.Button(text="vcg - ZOOM" , command=logavcg7)
botaologavcg7.grid(row=24, column=0, columnspan=1)

botaologavcg8 = tk.Button(text="vcg - Skyhub" , command=logavcg8)
botaologavcg8.grid(row=25, column=0, columnspan=1)

mensagemwallita = tk.Label(text="Wallita",fg='white', bg='blue')
mensagemwallita.grid(row=0, column=1, columnspan=1)

botaologawallita = tk.Button(text="Wallita - Kabum" , command=logawallita)
botaologawallita.grid(row=1, column=1, columnspan=1)

botaologawallita2 = tk.Button(text="Wallita - Via Varejo" , command=logawallita2)
botaologawallita2.grid(row=2, column=1, columnspan=1)

botaologawallita3 = tk.Button(text="Wallita - Magalu" , command=logawallita3)
botaologawallita3.grid(row=3, column=1, columnspan=1)

botaologawallita4 = tk.Button(text="Wallita - Carrefour" , command=logawallita4)
botaologawallita4.grid(row=4, column=1, columnspan=1)

mensagemsiberian = tk.Label(text="Siberian",fg='white', bg='blue')
mensagemsiberian.grid(row=5, column=1, columnspan=1)

botaologadavaldac = tk.Button(text="Valdac - Dafiti" , command=logadavaldac)
botaologadavaldac.grid(row=6, column=1, columnspan=1)

mensagemtommy = tk.Label(text="Tommy Hilfiger",fg='white', bg='blue')
mensagemtommy.grid(row=7, column=1, columnspan=1)

botaologatommy = tk.Button(text="Tommy Hilfiger - Skyhub" , command=logatommy)
botaologatommy.grid(row=8, column=1, columnspan=1)

mensagemdewalt = tk.Label(text="Dewalt",fg='white', bg='blue')
mensagemdewalt.grid(row=9, column=1, columnspan=1)

botaologadewalt = tk.Button(text="Dewalt - Via Varejo" , command=logadewalt)
botaologadewalt.grid(row=10, column=1, columnspan=1)

mensagemblackdecker = tk.Label(text="Black & Decker",fg='white', bg='blue')
mensagemblackdecker.grid(row=11, column=1, columnspan=1)

botaologablack = tk.Button(text="Black & Decker - Via Varejo" , command=logablack)
botaologablack.grid(row=12, column=1, columnspan=1)

mensagemtigre = tk.Label(text="Tigre",fg='white', bg='blue')
mensagemtigre.grid(row=13, column=1, columnspan=1)

botaologatigre = tk.Button(text="Tigre - Via Varejo" , command=logatigre)
botaologatigre.grid(row=14, column=1, columnspan=1)

botaologatigre1 = tk.Button(text="Tigre - B2W" , command=logatigre1)
botaologatigre1.grid(row=15, column=1, columnspan=1)

botaologatigre2 = tk.Button(text="Tigre - Carrefour" , command=logatigre2)
botaologatigre2.grid(row=16, column=1, columnspan=1)

botaologatigre3 = tk.Button(text="Tigre - Leroy Merlin" , command=logatigre3)
botaologatigre3.grid(row=17, column=1, columnspan=1)

botaologatigre4 = tk.Button(text="Tigre - Magalu" , command=logatigre4)
botaologatigre4.grid(row=18, column=1, columnspan=1)

botaologatigre5 = tk.Button(text="Tigre - Skyhub" , command=logatigre5)
botaologatigre5.grid(row=19, column=1, columnspan=1)

mensagemhoneywell = tk.Label(text="Honeywell",fg='white', bg='blue')
mensagemhoneywell.grid(row=20, column=1, columnspan=1)

botaologahoneywell = tk.Button(text="Honeywell - Carrefour" , command=logahoneywell)
botaologahoneywell.grid(row=21, column=1, columnspan=1)

botaologahoneywell1 = tk.Button(text="Honeywell - Leroy Merlin" , command=logahoneywell1)
botaologahoneywell1.grid(row=22, column=1, columnspan=1)

botaologahoneywell2 = tk.Button(text="Honeywell - Magalu" , command=logahoneywell2)
botaologahoneywell2.grid(row=23, column=1, columnspan=1)

botaologahoneywell3 = tk.Button(text="Honeywell - Magalu Ouro" , command=logahoneywell3)
botaologahoneywell3.grid(row=24, column=1, columnspan=1)

botaologahoneywell4 = tk.Button(text="Honeywell - Via Varejo" , command=logahoneywell4)
botaologahoneywell4.grid(row=25, column=1, columnspan=1)

mensagemtiojoao = tk.Label(text="Tio João",fg='white', bg='blue')
mensagemtiojoao.grid(row=0, column=2, columnspan=1)

botaologatiojoao = tk.Button(text="Tio João - B2W" , command=logatiojoao)
botaologatiojoao.grid(row=1, column=2, columnspan=1)

botaologatiojoao2 = tk.Button(text="Tio João - Carrefour" , command=logatiojoao2)
botaologatiojoao2.grid(row=2, column=2, columnspan=1)

botaologatiojoao3 = tk.Button(text="Tio João - GPA" , command=logatiojoao3)
botaologatiojoao3.grid(row=3, column=2, columnspan=1)

botaologatiojoao4 = tk.Button(text="Tio João - Magalu" , command=logatiojoao4)
botaologatiojoao4.grid(row=4, column=2, columnspan=1)

botaologatiojoao5 = tk.Button(text="Tio João - Syhub" , command=logatiojoao3)
botaologatiojoao5.grid(row=5, column=2, columnspan=1)

botaologatiojoao6 = tk.Button(text="Tio João - Via Varejo" , command=logatiojoao6)
botaologatiojoao6.grid(row=6, column=2, columnspan=1)

botaologatiojoao7 = tk.Button(text="Tio João - Droga Raia" , command=logatiojoao7)
botaologatiojoao7.grid(row=7, column=2, columnspan=1)

mensagemsolutions2go = tk.Label(text="Solutions2Go",fg='white', bg='blue')
mensagemsolutions2go.grid(row=8, column=2, columnspan=1)

botaologasolutions2go = tk.Button(text="Solutions2go - Carrefour" , command=logasolutions2go)
botaologasolutions2go.grid(row=9, column=2, columnspan=1)

mensagemlogabomdebeer = tk.Label(text="Bom de Beer",fg='white', bg='blue')
mensagemlogabomdebeer.grid(row=10, column=2, columnspan=1)

botaologabomdebeer = tk.Button(text="Bom de Beer - B2W" , command=logabomdebeer)
botaologabomdebeer.grid(row=11, column=2, columnspan=1)

botaologabomdebeer2 = tk.Button(text="Bom de Beer - Carrefour" , command=logabomdebeer2)
botaologabomdebeer2.grid(row=12, column=2, columnspan=1)

botaologabomdebeer3 = tk.Button(text="Bom de Beer - GPA" , command=logabomdebeer3)
botaologabomdebeer3.grid(row=13, column=2, columnspan=1)

botaologabomdebeer4 = tk.Button(text="Bom de Beer - Magalu" , command=logabomdebeer4)
botaologabomdebeer4.grid(row=14, column=2, columnspan=1)

botaologabomdebeer5 = tk.Button(text="Bom de Beer - Via Varejo" , command=logabomdebeer5)
botaologabomdebeer5.grid(row=15, column=2, columnspan=1)

botaologabomdebeer6 = tk.Button(text="Bom de Beer - Skyhub" , command=logabomdebeer6)
botaologabomdebeer6.grid(row=16, column=2, columnspan=1)

botaologabomdebeer7 = tk.Button(text="Bom de Beer - Droga Raia" , command=logabomdebeer7)
botaologabomdebeer7.grid(row=17, column=2, columnspan=1)

botaologabomdebeer8 = tk.Button(text="Bom de Beer - Riachuelo" , command=logabomdebeer8)
botaologabomdebeer8.grid(row=18, column=2, columnspan=1)

mensagemlogabrandili = tk.Label(text="Brandili",fg='white', bg='blue')
mensagemlogabrandili.grid(row=19, column=2, columnspan=1)

botaologabrandili = tk.Button(text="Brandili - B2W" , command=logabrandili)
botaologabrandili.grid(row=20, column=2, columnspan=1)

botaologabrandili2 = tk.Button(text="Brandili - Dafiti" , command=logabrandili2)
botaologabrandili2.grid(row=21, column=2, columnspan=1)

botaologabrandili3 = tk.Button(text="Brandili - Magazine Luiza" , command=logabrandili3)
botaologabrandili3.grid(row=22, column=2, columnspan=1)

botaologabrandili4 = tk.Button(text="Brandili - Ri Happy" , command=logabrandili4)
botaologabrandili4.grid(row=23, column=2, columnspan=1)

botaologabrandili5 = tk.Button(text="Brandili - Skyhub" , command=logabrandili5)
botaologabrandili5.grid(row=24, column=2, columnspan=1)

botaologabrandili6 = tk.Button(text="Brandili - Riachuelo" , command=logabrandili6)
botaologabrandili6.grid(row=25, column=2, columnspan=1)

mensagemlogabrandili2 = tk.Label(text="Brandili",fg='white', bg='blue')
mensagemlogabrandili2.grid(row=0, column=3, columnspan=1)

mensagemlogabrandili3 = tk.Label(text="Brandili",fg='white', bg='blue')
mensagemlogabrandili3.grid(row=0, column=4, columnspan=1)

mensagemlogabrandili4 = tk.Label(text="Brandili",fg='white', bg='blue')
mensagemlogabrandili4.grid(row=0, column=5, columnspan=1)

mensagemlogabrandili5 = tk.Label(text="Brandili",fg='white', bg='blue')
mensagemlogabrandili5.grid(row=0, column=6, columnspan=1)

mensagemlogabrandili6 = tk.Label(text="Brandili",fg='white', bg='blue')
mensagemlogabrandili6.grid(row=0, column=7, columnspan=1)

window.mainloop()
# Out:
# Page is ready!
# Page is ready!
