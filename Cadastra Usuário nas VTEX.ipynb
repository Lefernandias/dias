# %%
# login na vtex

from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.remote.webelement import WebElement
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import time
import pyautogui
from selenium.webdriver.support.select import Select
import pandas as pd
import urllib

navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")

dados = pd.read_excel ("dados.xlsx" )
#Sobre_nome = dados[ "Sobre_nome"]

#def cadastro():
for i, nome in enumerate(dados['Nome_completo' ]):  
    Sobre_nome = dados.loc[i, "Sobre_nome"]
    login = dados.loc[i, "Login"]
    email = dados.loc[i, "E-mail"]
    yami = dados.loc[i, "Gp_Yami"]
    silt = dados.loc[i, "Gp_Silt"]
    vtex = dados.loc[i, "Gp_Vtex"]
    abacos = dados.loc[i,"Gp_Abacos"]
    magento = dados.loc[i, "Gp_Magento"]

#print(dados.info())    
#display(dados)
#print(nome)
#print(Sobre_nome)
#print(yami)
#print(silt)
#print(vtex)
#print(abacos)
#print(magento)

lojas = pd.read_excel (r"C:\Users\leandro.dias\jupiter\accout_vtex.xlsx" )
#display(lojas)

# loga primeiro para pegar sessão do Google
navegador.get("https://synapcom.myvtex.com/admin/users")
delay =5
try:
    myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'email')))
    print("Page is ready!")
except TimeoutException:
    print("Loading took too much time!")
navegador.find_element_by_xpath('//*[@id="render-admin.login-legacy.home"]/div/div/div/div[1]/div[2]/div[1]/div[2]/div[2]/div[2]').send_keys(Keys.ENTER)

time.sleep(3)

navegador.find_element_by_xpath('//*[@id="identifierId"]').send_keys("leandro.dias@synapcom.com.br" + Keys.ENTER)
#navegador.find_element_by_xpath('//*[@id="identifierId"]').send_keys(f"{magento}" + Keys.ENTER) > mandar variavel
time.sleep(4)

navegador.find_element_by_xpath('//*[@id="password"]/div[1]/div/div[1]/input').send_keys("Synapcom2022@@" + Keys.ENTER)

          
time.sleep(15)
#def cadastro():

#executa o looping nas lojas

for i, conta in enumerate(lojas['conta' ]):
    URL = lojas.loc[i,"URL"]
    print(conta)
    link = f"https://{conta}.myvtex.com/admin/license-manager/#/user-details"
    navegador.get(link)
    myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'email')))
    print("Page is ready!")
    delay = 3
    navegador.find_element_by_xpath('//*[@id="render-admin.login-legacy.home"]/div/div/div/div[1]/div[2]/div[1]/div[2]/div[2]/div[2]').send_keys(Keys.ENTER)
    time.sleep(10)
    #navegador.find_element(By.name ,'Adicionar perfis').click()
    #navegador.find_element_by_xpath('//*[@id="render-admin.app.admin-users.new-user"]').send_keys("leandro.dias@synapcom.com.br")
    navegador.find_element_by_xpath('//*[@id="add-email-container"]').click()
    #navegador.find_element_by_xpath('user-search-input').click()
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="add-email-container"]').send_keys("leandro.dias@synapcom.com.br")
    time.sleep(3)
    navegador.find_elements_by_id('user-search-input').click()
    time.sleep(1)

#navegador.quit()
    #navegador.find_element_by_xpath('//body/div[@id='render-admin.container']/div[1]/div[1]/div[1]/div[2]/main[1]/iframe[1]').click()
    #time.sleep(5)
    #navegador.find_element_by_xpath('//body[1]/iv[2]/div[1]/div[1]/div[1]/div[1]/div[2]/div[1]/div[1]/div[1]/div[1]/div[1]/div[1]/label[1]/div[1]').click()
    #time.sleep(5)
    #navegador.find_element_by_xpath('body.bg-base:nth-child(2) div.render-container.render-route-admin-app-admin-users-new-user:nth-child(2) div.render-provider div.w-100.h-100.overflow-auto div.styleguide__layout.flex.justify-center.pb7.bg-muted-5.min-vh-100 div.w-100.mw8 div.layout__container.ph7-ns div.styleguide__pageBlock.flex.flex-column div.flex.flex-column.flex-row-ns.mb5-ns div.w-100.mb0-ns.mb5 div.styleguide__box.bg-base.t-body.c-on-base.br3.b--muted-4.ba.pa7 div:nth-child(1) div.mb5 label.vtex-input.w-100 > div.vtex-input-prefix__group.flex.flex-row.items-stretch.overflow-hidden.br2.bw1.b--solid.b--muted-4.hover-b--muted-3.h-regular').click()
    #time.sleep(5)
    #navegador.find_element_by_xpath('/html[1]/body[1]/div[2]/div[1]/div[1]/div[1]/div[1]/div[2]/div[1]/div[1]/div[1]/div[1]/div[1]/div[1]/label[1]/div[1]').click()

   #body.bg-base:nth-child(2) div.render-container.render-route-admin-app-admin-users-new-user:nth-child(2) div.render-provider div.w-100.h-100.overflow-auto div.styleguide__layout.flex.justify-center.pb7.bg-muted-5.min-vh-100 div.w-100.mw8 div.layout__container.ph7-ns div.styleguide__pageBlock.flex.flex-column div.flex.flex-column.flex-row-ns.mb5-ns div.w-100.mb0-ns.mb5 div.styleguide__box.bg-base.t-body.c-on-base.br3.b--muted-4.ba.pa7 div:nth-child(1) div.mb5 label.vtex-input.w-100 > div.vtex-input-prefix__group.flex.flex-row.items-stretch.overflow-hidden.br2.bw1.b--solid.b--muted-4.hover-b--muted-3.h-regular
   #//*[@id="render-admin.app.admin-users.new-user"]/div/div/div[1]/div/div[2]/div/div/div/div/div[2]/div[1]/div/button
   #//*[@id="render-admin.app.admin-users.new-user"]/div/div/div[1]/div/div[2]/div/div/div/div/div[2]/div[1]/div/button/div
   #//*[@id="render-admin.app.admin-users.new-user"]/div/div/div[1]/div/div[2]/div/div/div/div/div[2]/div[1]/div/button/div
   #//*[@id="render-admin.app.admin-users.new-user"]/div/div/div[1]/div/div[2]/div/div/div/div/div[2]/div[1]/div/button/div/span
   #//*[@id="render-admin.app.admin-users.new-user"]/div/div/div[1]/div/div[2]/div/div/div/div/div[2]/div[1]/div/button/div/span/div[2]
   #/html[1]/body[1]/div[2]/div[1]/div[1]/div[1]/div[1]/div[2]/div[1]/div[1]/div[1]/div[1]/div[1]/div[1]/label[1]/div[1]

    #myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'email')))
    #print("Page is ready!")
    #except TimeoutException:
    #print("Loading took too much time!")
    #navegador.find_element_by_xpath('//*[@id="render-admin.login-legacy.home"]/div/div/div/div[1]/div[2]/div[1]/div[2]/div[2]/div[2]').send_keys(Keys.ENTER)
    #time.sleep(3)

    #navegador.find_element_by_xpath('//*[@id="identifierId"]').send_keys("leandro.dias@synapcom.com.br" + Keys.ENTER)
    #time.sleep(2)

    #navegador.find_element_by_xpath('//*[@id="password"]/div[1]/div/div[1]/input').send_keys("Synapcom2022@" + Keys.ENTER)

          
#time.sleep(30)

#//*[@id="render-admin.app.admin-users.new-user"]/div/div/div[1]/div/div[2]/div/div/div/div/div[2]/div[1]/div

# ler dados da loja url noa aba vtex
# ler dados do usuário
# ler permissões

# fazer looping de lojas com o mesmo usuário
# Out:
# C:\Users\leandro.dias\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# Page is ready!
# calvinklein
# Page is ready!
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-2-b18bc5fbff1f> in <module>
#      79     #navegador.find_element(By.name ,'Adicionar perfis').click()
#      80     #navegador.find_element_by_xpath('//*[@id="render-admin.app.admin-users.new-user"]').send_keys("leandro.dias@synapcom.com.br")
# ---> 81     navegador.find_element_by_xpath('//*[@id="add-email-container"]').click()
#      82     #navegador.find_element_by_xpath('user-search-input').click()
#      83     time.sleep(1)
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
# ...

# %%
import requests
import pandas as pd

#montar base de dados
#fazer laço de dados do usuário
#Fazer laço do request


dados = pd.read_excel ("dados.xlsx" )

url = "f"https://{conta}.vtexcommercestable.com.br/api/license-manager/users"

payload = {
    "f"name": "Leandro Dias",
    "email": "lefernandias@hotmail.com"
}
headers = {
    "Content-Type": "application/json",
    "X-VTEX-API-AppKey": "vtexappkey-larocheposay-OUTVAH",
    "X-VTEX-API-AppToken": "PQEMPUJXXBWADNETHVIRYSJSLNGABVGVXNJJXQHJAXUYLSWBHSVRUVQWGMACOIWBVACQEUWRNZQAYLGTQFTIZOBBXMCKPFVRASDLPGXMWEEVEPXUGHLJOOCGZBTRSLCI"
}

response = requests.request("POST", url, json=payload, headers=headers)

print(response.text)
# Out:
# {"id":"d5b9f4d9197d4cd9ad8ff78fdf107e55","email":"lefernandias@hotmail.com","name":"Leandro Dias"}
