# %%
import requests
import json

url = "https://calvinklein.vtexcommercestable.com.br/api/oms/pvt/orders/v720216494ck-01"

headers = {
    "Accept": "application/json",
    "Content-Type": "application/json",
    "X-VTEX-API-AppKey": "vtexappkey-calvinklein-FZXXYD",
    "X-VTEX-API-AppToken": "DUYZKHNMOEYNZRLALUNTKYIIBNYEJNHRPZOWVNCHJBUVUQFIKBMVLFVFMQYXIJCBXGYACOFYRGKIDNOKHQUIAMFKDJKFOFZZYTXNSFFWVODFVMBYBOPSPUAKANWTDZKM"
}

response_ord = requests.request("GET", url, headers=headers)
response_ord = response_ord.json()
response_ord_ped = response_ord['orderId']
response_ord_seq = response_ord['sequence']
response_ord_sta = response_ord['status']
#print(response_ord)
display(response_ord)
# Out:
# {'orderId': 'v720216494ck-01',
#  'sequence': '720216494',
#  'marketplaceOrderId': '',
#  'marketplaceServicesEndpoint': 'http://oms.vtexinternal.com.br/api/oms?an=calvinklein',
#  'sellerOrderId': '00-v720216494ck-01',
#  'origin': 'Marketplace',
#  'affiliateId': '',
#  'salesChannel': '1',
#  'merchantName': None,
#  'status': 'invoiced',
#  'statusDescription': 'Faturado',
#  'value': 19042,
#  'creationDate': '2021-05-25T14:37:26.5770666+00:00',
#  'lastChange': '2021-05-26T12:05:20.6916224+00:00',
#  'orderGroup': 'v720216494ck',
#  'totals': [{'id': 'Items', 'name': 'Total dos Itens', 'value': 20300},
#   {'id': 'Discounts', 'name': 'Total dos Descontos', 'value': -1990},
#   {'id': 'Shipping', 'name': 'Total do Frete', 'value': 732},
#   {'id': 'Tax', 'name': 'Total da Taxa', 'value': 0}],
#  'items': [{'uniqueId': 'E219F15D6DAA4920839D849C6803BFFC',
#    'id': '2112488',
#    'productId': '2024081',
#    'ean': '7909621309222',
#    'lockId': '00-v720216494ck-01',
# ...
