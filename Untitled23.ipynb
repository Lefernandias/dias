# %%
import pyautogui
import time

from datetime import datetime
today= datetime.today().strftime('%d-%m-%y')
print("Today's date:", today)

# executa o aplicativo do abacos e faz login
def loga():
    time.sleep(20)
    #pyautogui.alert ('Processo cadastro de unidade de negocio será iniciado! ') # exibe mensagem no desktop para inico do programa
    pyautogui.press('winleft') # função que clica no botão windows do mouse 
    time.sleep(1) #tempo de espera para iniciar proxima função
    pyautogui.write('C:\Aplicacao\ABACOS.EXE')  # insere o endereço do executavel do kpl na barra de busca do menu do desktop
    pyautogui.PAUSE = 1.0 #tempo de espera para iniciar proxima função 
    pyautogui.press('enter') #Executa o endereço inserido na busca
    time.sleep(1) #tempo de espera para iniciar proxima função 
    pyautogui.moveTo (672, 672) # digitar no campo que informa o nome do usuário
    pyautogui.write('leandrofer') # função que insere o nome do usuário
    pyautogui.PAUSE = 0.5 #tempo de espera para iniciar proxima inserção
    pyautogui.press('enter') #função que da enter para cursor pular de campoS
    #pyautogui.moveTo (667, 398)
    pyautogui.write('Synapcom2022@@') #função que insere a senha do usuário
    pyautogui.PAUSE = 0.8 #tempo de espera para iniciar proxima inserçãoS
    pyautogui.moveTo (638, 436) # clica no campo de logar
    pyautogui.doubleClick(button='left') # duplo clique na campo de logar
    time.sleep(60) #tempo de espera para finalizar o programa
    

# entra na tela de nota fiscal de entrada
def menu():
    #pyautogui.alert ('Processo de aprovação de notas fiscais será iniciado ')
    time.sleep(30) #aguarda 10 segundos 
    pyautogui.moveTo (67, 637) #clica na barra de busca do menu
    time.sleep(5) #aguarda 1 segundoc
    pyautogui.doubleClick(button='left') #duplo click na barra
    pyautogui.write('digitar') #Digita o atalho
    pyautogui.press('enter') #função que da enter para cursor pular de campo
    pyautogui.moveTo (112, 302) # Point(x=112, y=302)
    pyautogui.doubleClick(button='left')
    time.sleep(60)

# insere os parametros de busca das notas fiscais
def busca(): #busca
    time.sleep(20)
    pyautogui.PAUSE = 1
    pyautogui.moveTo (246, 235) # posiciona o cursor no campo de unidade de negocio
    pyautogui.doubleClick(button='left') # efetua duplo clique no campo de unidadde de negocio
    pyautogui.write('DiGI') # inserer o numero da unidade de negocio
    pyautogui.press('enter') # insere enter para fixar o numero da unidade de negocio no campo
    pyautogui.press('TAB')
    pyautogui.press('TAB')# preciosa tab do teclado para pular para o campo status
    pyautogui.write('SY - COMPRAS') # insere a informação de status aguardando aprovação
    pyautogui.press('enter')
    pyautogui.press('TAB')
    #pyautogui.press('TAB')
    #pyautogui.press('TAB')
    #pyautogui.write('08122021')
    pyautogui.press('enter')
    #pyautogui.write('08122021')
    pyautogui.press('enter')
    pyautogui.press('enter')
    pyautogui.press('enter')
    pyautogui.write('1924541-43C0')
    # preciona enear para fixar a informação no campo
    time.sleep(2) #aguarda 1 segundo para o abacos realizar a busca
    pyautogui.hotkey('shift', 'enter')
    #pyautogui.moveTo (1337, 170) #posciona o cursor do mouse para o botão de filtrar
    #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar 
    time.sleep(30) #aguarda 1 segundo para o abacos realizar a busca
    
    
def atualiza():
    time.sleep(2)
    pyautogui.hotkey('shift', 'enter')
    #pyautogui.moveTo (1337, 170) #posciona o cursor do mouse para o botão de filtrar
    #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar 
    time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
    Notafiscal()


def filtra():
    time.sleep(20)
    pyautogui.moveTo (92, 396)  # Posiciona o cursor na lista de nota e verifica se existe registros
    pyautogui.click(button='left') #clica na posiçõa da listagem da nota
    time.sleep(0.4)# clica na posiçõa da listagem da nota
    

def Notafiscal():
    time.sleep(10)
    pyautogui.moveTo (92, 396) #posiciona o mouse para a primeira posição da listagem das notas fiscais
    time.sleep(2)
    pyautogui.click(button='left') # executa um clique simples para marcar a nota fiscal
    time.sleep(2)
    pyautogui.press('F5')
    time.sleep(3)
    pyautogui.press('TAB')
    time.sleep(1)
    pyautogui.press('TAB')
    time.sleep(1)
    pyautogui.press('TAB')
    time.sleep(1)
    #pyautogui.press('TAB')
    pyautogui.write(f'{today}')
    time.sleep(1)
    pyautogui.press('Enter')
    time.sleep(1)
    pyautogui.write('SY - CONS')
    time.sleep(10)
    pyautogui.press('Enter')
    time.sleep(90)
    pyautogui.press('F10')
    time.sleep(3)
    pyautogui.press('S')
    #pyautogui.press('Enter')
    time.sleep(120)
    pyautogui.press('ESC')
    time.sleep(1)
    pyautogui.press('F4')
    time.sleep(1)
    pyautogui.press('C')
    time.sleep(2)
    #pyautogui.press('F4')
    pyautogui.press('F10')
    time.sleep(1)
    pyautogui.press('S')
    time.sleep(2)
    pyautogui.press('Enter')
    time.sleep(2)
    pyautogui.write('girafa')
    time.sleep(2)
    pyautogui.press('Enter')
    time.sleep(30)
    atualiza()
    

def fechar():
    pyautogui.press('ESC')
    time.sleep(1)
    pyautogui.press('ESC')
    time.sleep(1)
    print ('Fechou Programa') #fecha e mata a programa
    pyautogui.FAILSAFE = False
    exit()
    pyautogui.alert ('Acabou ')
      
    
def loopazul():
    time.sleep(8)
    pyautogui.PAUSE = 2.0 
    pixazul = pyautogui.pixel(1151, 393)# coleta a cor aul da linha da nota buscada
    pyautogui.FAILSAFE = True
    time.sleep(3)
    pixazul[2] # retorna o valor da linha azul do retorno da função anterior
    a = pixazul[2]
    b = 215
    time.sleep(1)

    if a == b:
     Notafiscal()

    else:
     fechar()





#execução
#loga()
#menu()
#busca()
filtra()
loopazul()
# Out:
# Today's date: 09-12-21
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-a2579b4de44d> in <module>
#     172 #busca()
#     173 filtra()
# --> 174 loopazul()
#
# <ipython-input-7-a2579b4de44d> in loopazul()
#     158
#     159     if a == b:
# --> 160      Notafiscal()
#     161
#     162     else:
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     132     pyautogui.press('Enter')
#     133     time.sleep(30)
# --> 134     atualiza()
#     135
#     136
#
# <ipython-input-7-a2579b4de44d> in atualiza()
#      77     #pyautogui.doubleClick(button='left') #executa duplo clique no botão filtrar
#      78     time.sleep(10) #aguarda 1 segundo para o abacos realizar a busca
# ---> 79     Notafiscal()
#      80
#      81
#
# <ipython-input-7-a2579b4de44d> in Notafiscal()
#     130     pyautogui.write('girafa')
#     131     time.sleep(2)
# --> 132     pyautogui.press('Enter')
#     133     time.sleep(30)
#     134     atualiza()
#
# ~\Anaconda3\lib\site-packages\pyautogui\__init__.py in wrapper(*args, **kwargs)
#     585         failSafeCheck()
#     586         returnVal = wrappedFunction(*args, **kwargs)
# --> 587         _handlePause(kwargs.get("_pause", True))
#     588         return returnVal
#     589
#
# ~\Anaconda3\lib\site-packages\pyautogui\__init__.py in _handlePause(_pause)
#     629     if _pause:
#     630         assert isinstance(PAUSE, int) or isinstance(PAUSE, float)
# --> 631         time.sleep(PAUSE)
#     632
#     633
#
# KeyboardInterrupt:
