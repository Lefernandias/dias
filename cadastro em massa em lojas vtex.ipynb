# %%
import pandas as pd
import requests

lojas = pd.read_excel ("accout_vtex.xlsx" )
dado2 = pd.read_excel ("dado2.xlsx" )
display(lojas)
display(dado2)


import requests


for 
url = "https://calvinklein.vtexcommercestable.com.br/api/license-manager/users"

payload = {
    "name": "will stone",
    "email": "wills@wilbs.com"
}
headers = {
    "Content-Type": "application/json",
    "X-VTEX-API-AppKey": "vtexappkey-calvinklein-VWGWCN",
    "X-VTEX-API-AppToken": "AEBEDGUFSPUOCUUBGERZHEQZOMBLPNVYPCNKAIWJUKDCLLRZZKBPJTLVOCPQEJQFUVYZHKBYHIFXANNDVCLEMGPVRRWXSFFLUYIPMRSPJCIAONVAOLUBXLSNGCIPNDGB"
}

response = requests.request("POST", url, json=payload, headers=headers)

print(response.text)

















#def loga():
    #for i, conta in enumerate(lojas['conta' ]):
        #ky = lojas.loc[i,"appKey"]
        #tok = lojas.loc[i,"appToken"]
        #url = f"https://{conta}.vtexcommercestable.com.br/api/license-manager/users"
        #header = {"Content-Type": "application/json", f"X-VTEX-API-AppKey": {ky},  f"X-VTEX-API-AppToken": {tok}
        #cadastro()
        #request()
        #json = payload
        #for i, nome in enumerate(dado2['Nome_completo' ]):  
                #email = dado2.loc[i, "E-mail"]
                #payload = {"name": (nome), "email": (email) }
        
       
        
        #response = requests.request("POST", url, json, headers)
      
                   
#def cadastro():
        #for i, nome in enumerate(dado2['Nome_completo' ]):  
            #email = dado2.loc[i, "E-mail"]
            #payload = {"name": {nome}, "email": {email} }
            #response = requests.request("POST", url, json=payload, headers=headers)      
                
                
#def request():
    #response = requests.request("POST", url, json=payload, headers=headers)         
    

#loga() 
#print(response.text)
# Out:
#           conta                        appToken  \
# 0   calvinklein   vtexappkey-calvinklein-VWGWCN
# 1   lojamarisol   vtexappkey-lojamarisol-XIHNBH
# 2  larocheposay  vtexappkey-larocheposay-OUTVAH
#
#                                               appKey
# 0  AEBEDGUFSPUOCUUBGERZHEQZOMBLPNVYPCNKAIWJUKDCLL...
# 1  BUBVQARUWZUVVPZQNVLPUFNBDLHHHEIFDSNYQQXRIPSZFL...
# 2  PQEMPUJXXBWADNETHVIRYSJSLNGABVGVXNJJXQHJAXUYLS...
#       Nomecompleto Sobrenome         Login                    Email  \
# 0    Albert Wesker    Wesker  albertwesker  albert.wesker@gmail.com
# 1          Jumento       NaN           NaN    jumento@silver.com.br
# 2  Albert Wesker 2       NaN           NaN  albert.wesker@gmail.com
#
#                         GpYami              GpSilt          GpVtex   GpAbacos  \
# 0  Return Manager - Financeiro  CONTROLE DE AVARIA  Client_service  COMERCIAL
# 1                          NaN                 NaN             NaN        NaN
# ...
