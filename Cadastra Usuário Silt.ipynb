# %%
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.remote.webelement import WebElement
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import time
import pyautogui 
from selenium.webdriver.support.select import Select
import pandas as pd
import urllib

navegador = webdriver.Chrome("C:/Users/leandro.dias/Downloads/chromedriver.exe")

dados = pd.read_excel ("dados.xlsx" )

# função de login
def loga():
    navegador.get("https://www.b2wmarketplace.com.br/login")
    delay = 3
    try:
        myElem = WebDriverWait(navegador, delay).until(EC.presence_of_element_located((By.ID, 'main')))
        print("Page is ready!")
    except TimeoutException:
        print("Loading took too much time!")
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_loginText"]').send_keys("leandro.dias" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_passwordText"]').send_keys("Synapcom2022@@" + Keys.TAB)
    #navegador.get("https://www.calvinklein.com.br/kit-4-cuecas-low-rise-trunk-de-cotton-azul-branco-preto-mas2665_585900987/p")
    #time.sleep(5)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[2]/div[1]/form/div[1]/input').send_keys("arno_marketplace@synapcom.com.br" + Keys.TAB)
    #navegador.find_element_by_xpath('//*[@id="LoginDialog_armazemComboBox"]').send_keys(Keys.UP, Keys.RETURN) # Cajamar
    time.sleep(5)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[2]/div[1]/form/div[2]/input').send_keys("Arno@2021" + Keys.TAB)
    time.sleep(5)
    navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[2]/div[1]/form/button').click()
# função entrar no menu de cadastro
def menu():
    time.sleep(10)
    navegador.find_element_by_xpath('//*[@id="shipping-calculate-link"]').click()
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="summary-postal-code"]').send_keys("02213020" + Keys.ENTER)
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="tb-Controle-Cadastrar"]').click()
    
    
    
    
    
    
    
    

def cadastro2():
    time.sleep(8)
    navegador.find_element_by_xpath('//*[@id="UsuarioScreenDescriptor_nomeUsuarioCompleto"]').send_keys(f"{nome}" + Keys.TAB)
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="UsuarioScreenDescriptor_nomeUsuario"]').send_keys(f"{Sobre_nome}" + Keys.TAB)
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="UsuarioScreenDescriptor_senha"]').send_keys("Synapcom@2022" + Keys.TAB)
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="UsuarioScreenDescriptor_campoVirtual"]').send_keys("Synapcom@2022" + Keys.TAB)
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="UsuarioScreenDescriptor_tipoUsuario"]').click()
    time.sleep(3)
    #criar função que valida o tipo de permissão
    navegador.find_element_by_xpath('//*[@id="UsuarioScreenDescriptor_tipoUsuario"]').send_keys(Keys.DOWN)
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="UsuarioScreenDescriptor_tipoUsuario"]').send_keys(Keys.DOWN, Keys.RETURN)
    time.sleep(1)
    #fim da função
    navegador.find_element_by_xpath('//*[@id="UsuarioScreenDescriptor_departamento"]').send_keys("OPERACIONAL" + Keys.TAB) # criar base de setores da logistica
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="UsuarioScreenDescriptor_dataProximaAlteracao"]').send_keys("25/10/2050" + Keys.TAB)
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="UsuarioScreenDescriptor_email"]').send_keys(f"{email}" + Keys.TAB)
    time.sleep(1)
    navegador.find_element_by_xpath('//*[@id="CadastroWindow_salvarCadastrodeUsuárioButton"]').click()
    time.sleep(20)
    
    
# função de cadastro do usuário com looping na tabela
def cadastro():
     for i, nome in enumerate(dados['Nome_completo' ]):  
        Sobre_nome = dados.loc[i, "Sobre_nome"]
        login = dados.loc[i, "Login"]
        email = dados.loc[i, "E-mail"]
        yami = dados.loc[i, "Gp_Yami"]
        silt = dados.loc[i, "Gp_Silt"]
        vtex = dados.loc[i, "Gp_Vtex"]
        abacos = dados.loc[i,"Gp_Abacos"]
        magento = dados.loc[i, "Gp_Magento"]
        cadastro2()
       

#fecha o programa
def fim():   
    navegador.quit()

#seguencia de execução

loga()
menu()
cadastro()
fim()
# Out:
# C:\Users\leandro.dias\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# Page is ready!
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-1-95bd165fcff7> in <module>
#     100 #seguencia de execução
#     101
# --> 102 loga()
#     103 menu()
#     104 cadastro()
#
# <ipython-input-1-95bd165fcff7> in loga()
#      29     #navegador.get("https://www.calvinklein.com.br/kit-4-cuecas-low-rise-trunk-de-cotton-azul-branco-preto-mas2665_585900987/p")
#      30     #time.sleep(5)
# ---> 31     navegador.find_element_by_xpath('//*[@id="main"]/app-login/main/section/div[2]/div[1]/form/div[1]/input').send_keys("arno_marketplace@synapcom.com.br" + Keys.TAB)
# ...
